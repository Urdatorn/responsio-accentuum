# %% [markdown]
# This notebook contains the main compatibility scores for Pindar's odes, and the one-sided Monte Carlo permutation tests.

# %% [markdown]
# # Preparation

# %% [markdown]
# If first time, run the installation:

# %%
# %pip install -e ..

# %% [markdown]
# Make ROOT independent of where the Jupyter server is launched:

# %%
from pathlib import Path

def find_project_root(start: Path, markers=("pyproject.toml", ".git")):
    for p in [start] + list(start.parents):
        if any((p / m).exists() for m in markers):
            return p
    raise RuntimeError("Project root not found")

ROOT = find_project_root(Path.cwd())

# %% [markdown]
# We want stats on the data:
# - how many songs have each type of responsion (triadic/monolithic, strophic-antistrophic, epodic), and the
# - distribution of strophicities.

# %%
import xml.etree.ElementTree as ET

FOLDERS = {
    "triads": ROOT / "data" / "compiled" / "triads",
    "strophes": ROOT / "data" / "compiled" / "strophes"
}

def collect_ids(folder: Path) -> set[str]:
    ids: set[str] = set()
    for xml_path in folder.glob("*.xml"):
        try:
            tree = ET.parse(xml_path)
            for elem in tree.iter():
                resp_id = elem.attrib.get("responsion")
                if resp_id:
                    ids.add(resp_id)
        except Exception as exc:
            print(f"Warning: failed to parse {xml_path}: {exc}")
    return ids


results: dict[str, set[str]] = {}
for name, folder in FOLDERS.items():
    ids = collect_ids(folder)
    results[name] = ids

tri = results["triads"]
stro = results["strophes"]

print("###########################################")
print("\033[1;1mTHE 2 GENERA OF RESPONSION\033[0m")
print("###########################################")
print()

print(f"Total unique responsion id values across all folders:\n\t\033[1;32m{len(tri | stro)}\033[0m")
print("\tIDs:", ", ".join(sorted(tri | stro)))
print()

print(f"1. Triadic and simple responsion:\n\t\033[1;32m{len(tri)}\033[0m unique responsion id values")
if tri:
    print("\tIDs:", ", ".join(sorted(tri)))
    print("\n\tOf which:")
    print(f"\ti. the \033[1;32m{len(tri & stro)}\033[0m fully triadic odes (strophe-antistrophe-epode):\n\t", ", ".join(sorted(tri & stro)) or "None")
    print(f"\t\t \033[1;33mNB: these are common to both responsion types, and hence the main experimental focus of the project\033[0m")
    print(f"\n\tii. the \033[1;32m{len(tri - stro)}\033[0m \"simple\" odes (no antistrophes or epodes):\n\t", ", ".join(sorted(tri - stro)) or "None")
print()

print(f"2. Strophe-antistrophe responsion:\n\t\033[1;32m{len(stro)}\033[0m unique responsion id values")
if stro:
    print("\tIDs:", ", ".join(sorted(stro)))
    print(f"\n\tOf which the \033[1;32m{len(stro - tri)}\033[0m 1-strophic odes with internal resp. only (epodes useless):\n\t", ", ".join(sorted(stro - tri)) or "None")
print()
# Out:
# ###########################################
# THE 2 GENERA OF RESPONSION
# ###########################################
#
# Total unique responsion id values across all folders:
# 	44
# 	IDs: is01, is02, is04, is05, is06, is07, is08, ne01, ne02, ne03, ne04, ne05, ne06, ne07, ne08, ne09, ne10, ne11, ol01, ol02, ol03, ol04, ol05, ol06, ol07, ol08, ol09, ol10, ol11, ol12, ol13, ol14, py01, py02, py03, py04, py05, py06, py07, py08, py09, py10, py11, py12
#
# 1. Triadic and simple responsion:
# 	40 unique responsion id values
# 	IDs: is01, is02, is04, is05, is06, is07, is08, ne01, ne02, ne03, ne04, ne05, ne06, ne07, ne08, ne09, ne10, ne11, ol01, ol02, ol03, ol05, ol06, ol07, ol08, ol09, ol10, ol13, ol14, py01, py02, py03, py04, py05, py06, py08, py09, py10, py11, py12
#
# 	Of which:
# 	i. the 33 fully triadic odes (strophe-antistrophe-epode):
# ...

# %%
fully_triadic_odes = (tri & stro)   # triadic-simple responsion type
simple_odes = (tri - stro)          # triadic-simple responsion type
one_strophic_odes = (stro - tri)    # strophic-antistrophic responsion type

assert len((fully_triadic_odes & simple_odes & one_strophic_odes)) == 0
assert len((fully_triadic_odes & simple_odes)) == 0
assert len((fully_triadic_odes & one_strophic_odes)) == 0
assert len((simple_odes & one_strophic_odes)) == 0

# %%
from collections import Counter

from responsio_accentuum import get_strophicity

##################################
### Triadic-simple responsion type
##################################

responsion_counts_triadic = get_strophicity(responsion_type="triadic-simple")

# for is08, ne02, ne04, ne09, ol14, py06, py12, the print should have a parenthesis saying (simple)

items = sorted(responsion_counts_triadic.items())

# split into two roughly equal halves
mid = (len(items) + 1) // 2
left = items[:mid]
right = items[mid:]

print(f"\033[1mTriadic-simple strophe counts for all {len(responsion_counts_triadic)} responsion IDs:\033[0m\n")

for i in range(mid):
    # left column
    rid_l, count_l = left[i]
    if rid_l in ["is08", "ne02", "ne04", "ne09", "ol14", "py06", "py12"]:
        left_text = f"{rid_l}: {count_l} strophes (simple)"
    else:
        left_text = f"{rid_l}: {count_l} strophes"

    # right column (if exists)
    if i < len(right):
        rid_r, count_r = right[i]
        if rid_r in ["is08", "ne02", "ne04", "ne09", "ol14", "py06", "py12"]:
            right_text = f"{rid_r}: {count_r} strophes (simple)"
        else:
            right_text = f"{rid_r}: {count_r} strophes"
    else:
        right_text = ""

    # print aligned columns
    print(f"{left_text:<45} {right_text}")

strophicity_counts = Counter(responsion_counts_triadic.values())

print("\n\033[1mResponsion IDs by strophicity:\033[0m\n")

for strophicity, n_responsion_ids in sorted(strophicity_counts.items()):
    print(f"{strophicity} strophes: {n_responsion_ids} responsion IDs")
    
mean_strophicity = sum(strophicity * n for strophicity, n in strophicity_counts.items()) / sum(n for _, n in strophicity_counts.items())
print(f"\n\033[1mMean strophicity:\033[0m {mean_strophicity:.2f} strophes per responsion ID")
# Out:
# Triadic-simple strophe counts for all 40 responsion IDs:
#
# is01: 4 strophes                              ol03: 3 strophes
# is02: 3 strophes                              ol05: 3 strophes
# is04: 5 strophes                              ol06: 5 strophes
# is05: 3 strophes                              ol07: 5 strophes
# is06: 3 strophes                              ol08: 4 strophes
# is07: 3 strophes                              ol09: 4 strophes
# is08: 7 strophes (simple)                     ol10: 5 strophes
# ne01: 4 strophes                              ol13: 5 strophes
# ne02: 5 strophes (simple)                     ol14: 2 strophes (simple)
# ne03: 4 strophes                              py01: 5 strophes
# ne04: 12 strophes (simple)                    py02: 4 strophes
# ne05: 3 strophes                              py03: 5 strophes
# ne06: 3 strophes                              py04: 13 strophes
# ne07: 5 strophes                              py05: 4 strophes
# ...

# %%
#########################################
### Strophic-antistrophic responsion type
#########################################

responsion_counts_strophic = get_strophicity(responsion_type="strophic-antistrophic")

items = sorted(responsion_counts_strophic.items())

# split into two roughly equal halves
mid = (len(items) + 1) // 2
left = items[:mid]
right = items[mid:]

print(f"\n\033[1mStrophic-antistrophic strophe counts for all {len(responsion_counts_strophic)} responsion IDs:\033[0m\n")

for i in range(mid):
    # left column
    rid_l, count_l = left[i]
    left_text = f"{rid_l}: {count_l} strophes"

    # right column (if exists)
    if i < len(right):
        rid_r, count_r = right[i]
        right_text = f"{rid_r}: {count_r} strophes"
    else:
        right_text = ""

    # print aligned columns
    print(f"{left_text:<45} {right_text}")

strophicity_counts = Counter(responsion_counts_strophic.values())

print("\n\033[1mResponsion IDs by strophicity:\033[0m\n")

for strophicity, n_responsion_ids in sorted(strophicity_counts.items()):
    print(f"{strophicity} strophes: {n_responsion_ids} responsion IDs")
    
mean_strophicity = sum(strophicity * n for strophicity, n in strophicity_counts.items()) / sum(n for _, n in strophicity_counts.items())
print(f"\n\033[1mMean strophicity:\033[0m {mean_strophicity:.2f} strophes per responsion ID")
# Out:
# Strophic-antistrophic strophe counts for all 37 responsion IDs:
#
# is01: 8 strophes                              ol06: 10 strophes
# is02: 6 strophes                              ol07: 10 strophes
# is04: 10 strophes                             ol08: 8 strophes
# is05: 6 strophes                              ol09: 8 strophes
# is06: 6 strophes                              ol10: 10 strophes
# is07: 6 strophes                              ol11: 2 strophes
# ne01: 8 strophes                              ol12: 2 strophes
# ne03: 8 strophes                              ol13: 10 strophes
# ne05: 6 strophes                              py01: 10 strophes
# ne06: 6 strophes                              py02: 8 strophes
# ne07: 10 strophes                             py03: 10 strophes
# ne08: 6 strophes                              py04: 26 strophes
# ne10: 10 strophes                             py05: 8 strophes
# ne11: 6 strophes                              py07: 2 strophes
# ...

# %%
from collections import Counter

##################################
### Fully triadic odes
##################################

responsion_counts_triadic = get_strophicity(responsion_type="triadic-simple")
responsion_counts_triadic = {rid: count for rid, count in responsion_counts_triadic.items() if rid in fully_triadic_odes}

strophicity_counts = Counter(responsion_counts_triadic.values())

print("\n\033[1mResponsion IDs by strophicity:\033[0m\n")

for strophicity, n_responsion_ids in sorted(strophicity_counts.items()):
    print(f"{strophicity} strophes: {n_responsion_ids} responsion IDs")
    
mean_strophicity = sum(strophicity * n for strophicity, n in strophicity_counts.items()) / sum(n for _, n in strophicity_counts.items())
print(f"\n\033[1mMean strophicity:\033[0m {mean_strophicity:.2f} strophes per responsion ID")
# Out:
# Responsion IDs by strophicity:
#
# 3 strophes: 10 responsion IDs
# 4 strophes: 10 responsion IDs
# 5 strophes: 12 responsion IDs
# 13 strophes: 1 responsion IDs
#
# Mean strophicity: 4.33 strophes per responsion ID

# %% [markdown]
# # Test statistics

# %% [markdown]
# We define two test statistics.
#
# The first flattens all normalized compatibility scores across all 11 379 metrical positions, and takes the mean.
#
# Let $T_{pos}$ denote this statistic:
#
# $$ T_{pos} = \frac{1}{11 379} \sum_{pos=1}^{11 379} \bar{x}_{pos}.$$
#
# To avoid longer songs weighing more, we also define a second test statistic that first averages the normalized compatibility scores within each song, and then takes the mean again across the 40 songs.
#
# Let $T_{song}$ denote this statistic:
#
# $$ T_{song} = \frac{1}{40} \sum_{s=1}^{40} \bar{x}_s.$$
#
# We are going to compute these test statistics for the Pindar corpus, and for 10 000 random baselines, and then perform a one-sided permutation test to see if the observed statistics are significantly higher than the baselines.

# %% [markdown]
# ## T_obs_pos

# %% [markdown]
# For reference, we here calculate all four different observed statistics for Pindar and the observed statistic for Bacchylides. Only the first two, calculated on the exact same set of odes, will be used for the permutation tests.

# %%
import pickle

from responsio_accentuum import compatibility_corpus, compatibility_canticum, compatibility_ratios_to_stats

corpus_path = ROOT / 'data/compiled/triads'
corpus_path_strophes = ROOT / 'data/compiled/strophes/'

corpus_score_pickle_path = ROOT / 'data/cache/all_comp_ratios.pkl'
corpus_score_pickle_path_strophes = ROOT / 'data/cache/all_comp_ratios_strophes.pkl'

if corpus_score_pickle_path.exists():
    with open(corpus_score_pickle_path, 'rb') as f:
        all_corpus_comp_scores = pickle.load(f)
else:
    print('Calculating all_corpus_comp_scores...')
    all_corpus_comp_scores = compatibility_corpus(corpus_path)
    with open(corpus_score_pickle_path, 'wb') as f:
        pickle.dump(all_corpus_comp_scores, f)

if corpus_score_pickle_path_strophes.exists():
    with open(corpus_score_pickle_path_strophes, 'rb') as f:
        all_corpus_comp_scores_strophes = pickle.load(f)
else:
    print('Calculating all_corpus_comp_scores_strophes...')
    all_corpus_comp_scores_strophes = compatibility_corpus(corpus_path_strophes)
    with open(corpus_score_pickle_path_strophes, 'wb') as f:
        pickle.dump(all_corpus_comp_scores_strophes, f)
        
# Innovation: we also want a score for the intersection, i.e. the 33 fully triadic odes

# Triadic-simple responsion type

pool = []
for ode in sorted(fully_triadic_odes):
    if ode[:2] == 'py':
        ode_path = corpus_path / f"ht_pythians_triads.xml"
        ratios = compatibility_canticum(ode_path, ode)
        pool.append(ratios)
    elif ode[:2] == 'ne':
        ode_path = corpus_path / f"ht_nemeans_triads.xml"
        ratios = compatibility_canticum(ode_path, ode)
        pool.append(ratios)
    elif ode[:2] == 'ol':
        ode_path = corpus_path / f"ht_olympians_triads.xml"
        ratios = compatibility_canticum(ode_path, ode)
        pool.append(ratios)
    elif ode[:2] == 'is':
        ode_path = corpus_path / f"ht_isthmians_triads.xml"
        ratios = compatibility_canticum(ode_path, ode)
        pool.append(ratios)
        
T_obs_pos_fully_triadic = compatibility_ratios_to_stats(pool) 

# Strophic-antistrophic responsion type (difference is in the data not in the code)

pool_strophic = []
for ode in sorted(fully_triadic_odes):
    if ode[:2] == 'py':
        ode_path = corpus_path_strophes / f"ht_pythians_strophes.xml"
        ratios = compatibility_canticum(ode_path, ode)
        pool_strophic.append(ratios)
    elif ode[:2] == 'ne':
        ode_path = corpus_path_strophes / f"ht_nemeans_strophes.xml"
        ratios = compatibility_canticum(ode_path, ode)
        pool_strophic.append(ratios)
    elif ode[:2] == 'ol':
        ode_path = corpus_path_strophes / f"ht_olympians_strophes.xml"
        ratios = compatibility_canticum(ode_path, ode)
        pool_strophic.append(ratios)
    elif ode[:2] == 'is':
        ode_path = corpus_path_strophes / f"ht_isthmians_strophes.xml"
        ratios = compatibility_canticum(ode_path, ode)
        pool_strophic.append(ratios)
        
T_obs_pos_fully_triadic_strophes = compatibility_ratios_to_stats(pool_strophic) 

# Bacchylides 

all_corpus_comp_scores_ba = compatibility_canticum(ROOT / 'data/compiled/extra/ba05.xml', 'ba05')

def count_leaves(obj):
    """Count all leaf (non-list) elements in a nested structure."""
    if isinstance(obj, list):
        return sum(count_leaves(item) for item in obj)
    else:
        return 1

# Calculate T_obs for each category
T_obs_pos_triads = compatibility_ratios_to_stats(all_corpus_comp_scores)
T_obs_triads_ba = compatibility_ratios_to_stats(all_corpus_comp_scores_ba) # For Bacchylides T_pos = T_song

T_obs_pos_strophes = compatibility_ratios_to_stats(all_corpus_comp_scores_strophes)

# Count total number of variables
total_fully_triadic = sum(count_leaves(lst) for lst in pool if lst)
total_fully_triadic_strophic = sum(count_leaves(lst) for lst in pool_strophic if lst)
total_triads = sum(count_leaves(lst) for lst in all_corpus_comp_scores)
total_triads_ba = sum(count_leaves(lst) for lst in all_corpus_comp_scores_ba)
total_strophes = sum(count_leaves(lst) for lst in all_corpus_comp_scores_strophes)

print ('\n--------------------------------------------')
print(f'\033[1;33mTRIADIC-SIMPLE RESPONSION: FULLY-TRIADIC ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_pos: \033[1;32m{T_obs_pos_fully_triadic:.4f}\033[0m')
print(f'Number of variables: {total_fully_triadic}')
print ('--------------------------------------------')

print ('\n--------------------------------------------')
print(f'\033[1;33mSTROPHIC-ANTISTROPHIC RESPONSION: FULLY-TRIADIC ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_pos: \033[1;32m{T_obs_pos_fully_triadic_strophes:.4f}\033[0m')
print(f'Number of variables: {total_fully_triadic_strophic}')
print ('--------------------------------------------')

print ('\n--------------------------------------------\n')

print ('--------------------------------------------')
print(f'\033[1;33mTRIADIC-SIMPLE RESPONSION: TRIADIC AND SIMPLE ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_pos: \033[1;32m{T_obs_pos_triads:.4f}\033[0m')
print(f'Number of variables: {total_triads}')

print()

print(f'\033[33mBacchylides\033[0m (Ba. 5) T (T_pos = T_song): \033[1;32m{T_obs_triads_ba:.5f}\033[0m')
print(f'Number of variables: {total_triads_ba}')
print ('--------------------------------------------')

print ('\n--------------------------------------------')
print(f'\033[1;33mSTROPHIC-ANTISTROPHIC RESPONSION: ALL STROPHIC-ANTISTROPHIC INCL. ONE-STROPHIC ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_pos: \033[1;32m{T_obs_pos_strophes:.4f}\033[0m')

print(f'Number of variables: {total_strophes}')
print ('--------------------------------------------')
# Out:
# --------------------------------------------
# TRIADIC-SIMPLE RESPONSION: FULLY-TRIADIC ODES
#
# Pindar: T_pos: 0.5276
# Number of variables: 9538
# --------------------------------------------
#
# --------------------------------------------
# STROPHIC-ANTISTROPHIC RESPONSION: FULLY-TRIADIC ODES
#
# Pindar: T_pos: 0.5566
# Number of variables: 3202
# --------------------------------------------
#
# --------------------------------------------
#
# --------------------------------------------
# TRIADIC-SIMPLE RESPONSION: TRIADIC AND SIMPLE ODES
#
# Pindar: T_pos: 0.5306
# Number of variables: 10337
#
# Bacchylides (Ba. 5) T (T_pos = T_song): 0.54751
# Number of variables: 221
# --------------------------------------------
#
# --------------------------------------------
# STROPHIC-ANTISTROPHIC RESPONSION: ALL STROPHIC-ANTISTROPHIC INCL. ONE-STROPHIC ODES
#
# Pindar: T_pos: 0.5714
# Number of variables: 3543
# --------------------------------------------

# %% [markdown]
# ## T_obs_song

# %% [markdown]
# Now let's also do $T_{song}$ for all responsion types and all three corpora (slightly more work to do here, since we need to average within songs first).
# All individual song scores are also printed.

# %%
from statistics import mean

from responsio_accentuum import compatibility_canticum, compatibility_ratios_to_stats
from responsio_accentuum import canticum_with_at_least_two_strophes

### The 33 fully triadic odes ###

# Triadic-simple responsion type

song_scores_fully_triadic_triads = {}
song_scores_fully_triadic_strophes = {}

responding_unit = ["triads", "strophes"]
for unit in responding_unit:
    in_folder_odes = ROOT / f"data/compiled/{unit}/"
    for ode in sorted(fully_triadic_odes):
        if ode[:2] == 'py':
            ode_path = in_folder_odes / f"ht_pythians_{unit}.xml"
        elif ode[:2] == 'ne':
            ode_path = in_folder_odes / f"ht_nemeans_{unit}.xml"
        elif ode[:2] == 'ol':
            ode_path = in_folder_odes / f"ht_olympians_{unit}.xml"
        elif ode[:2] == 'is':
            ode_path = in_folder_odes / f"ht_isthmians_{unit}.xml"

        # Check if the canticum exists and has at least 2 strophes
        if not canticum_with_at_least_two_strophes(ode_path, ode):
            raise ValueError(f"{ode} in {unit} does not have at least 2 responding units, skipping...")

        try:
            ode_ratios = compatibility_canticum(ode_path, ode)
            ode_comp = compatibility_ratios_to_stats(ode_ratios)

            if unit == "triads":
                song_scores_fully_triadic_triads[ode] = ode_comp
            elif unit == "strophes":
                song_scores_fully_triadic_strophes[ode] = ode_comp
        except Exception as e:
            print(f"Warning: Could not process {ode} in {unit}: {e}")
            continue

# Calculate T_obs_song
T_obs_song_fully_triadic_triads = mean(list(song_scores_fully_triadic_triads.values()))
T_obs_song_fully_triadic_strophes = mean(list(song_scores_fully_triadic_strophes.values()))

### 40 triadic and simple odes, and 37 strophic-antistrophic incl. one-strophic odes ###

song_scores_triads = {}
song_scores_strophes = {}

responding_unit = ["triads", "strophes"]
for unit in responding_unit:
    in_folder_odes = ROOT / f"data/compiled/{unit}/"
    if unit == "triads":
        odes = tri
    elif unit == "strophes":
        odes = stro
    for ode in sorted(odes):
        if ode[:2] == 'py':
            ode_path = in_folder_odes / f"ht_pythians_{unit}.xml"
        elif ode[:2] == 'ne':
            ode_path = in_folder_odes / f"ht_nemeans_{unit}.xml"
        elif ode[:2] == 'ol':
            ode_path = in_folder_odes / f"ht_olympians_{unit}.xml"
        elif ode[:2] == 'is':
            ode_path = in_folder_odes / f"ht_isthmians_{unit}.xml"

        # Check if the canticum exists and has at least 2 strophes
        if not canticum_with_at_least_two_strophes(ode_path, ode):
            raise ValueError(f"{ode} in {unit} does not have at least 2 responding units, skipping...")

        try:
            ode_ratios = compatibility_canticum(ode_path, ode)
            ode_comp = compatibility_ratios_to_stats(ode_ratios)

            if unit == "triads":
                song_scores_triads[ode] = ode_comp
            elif unit == "strophes":
                song_scores_strophes[ode] = ode_comp
        except Exception as e:
            print(f"Warning: Could not process {ode} in {unit}: {e}")
            continue

# Calculate T_obs_song
T_obs_song_triads = mean(list(song_scores_triads.values()))
T_obs_song_strophes = mean(list(song_scores_strophes.values()))

print(f'\033[1;33mTRIADIC-SIMPLE RESPONSION: FULLY-TRIADIC ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_obs_song: \033[1;32m{T_obs_song_fully_triadic_triads:.4f}\033[0m')

print(f'\033[1;33mSTROPHIC-ANTISTROPHIC RESPONSION: FULLY-TRIADIC ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_obs_song: \033[1;32m{T_obs_song_fully_triadic_strophes:.4f}\033[0m')

print(f'\033[1;33mTRIADIC-SIMPLE RESPONSION: TRIADIC AND SIMPLE ODES\033[0m\n')
print(f"\tT_obs_song_triads ({len(list(song_scores_triads))} songs): \033[1;32m{T_obs_song_triads:.4f}\033[0m")
print(f'\033[1;33mSTROPHIC-ANTISTROPHIC RESPONSION: ALL STROPHIC-ANTISTROPHIC INCL. ONE-STROPHIC ODES\033[0m\n')
print(f"\tT_obs_song_strophes ({len(list(song_scores_strophes))} songs): \033[1;32m{T_obs_song_strophes:.4f}\033[0m")
# Out:
# TRIADIC-SIMPLE RESPONSION: FULLY-TRIADIC ODES
#
# Pindar: T_obs_song: 0.5281
# STROPHIC-ANTISTROPHIC RESPONSION: FULLY-TRIADIC ODES
#
# Pindar: T_obs_song: 0.5593
# TRIADIC-SIMPLE RESPONSION: TRIADIC AND SIMPLE ODES
#
# 	T_obs_song_triads (40 songs): 0.5333
# STROPHIC-ANTISTROPHIC RESPONSION: ALL STROPHIC-ANTISTROPHIC INCL. ONE-STROPHIC ODES
#
# 	T_obs_song_strophes (37 songs): 0.5762

# %% [markdown]
# ## Individual canticum scores

# %%
print("\n######################")
print("TRIADIC-SIMPLE")
print("########################")

for ode in song_scores_triads:

    print('\n--------------------------------------------')
    print(f'\033[1;32m{ode}\033[0m')
    print(f'Ode comp: \033[1;32m{song_scores_triads[ode]:.4f}\033[0m (triads)')
    print('----------------------------------------------')
# Out:
# ######################
# TRIADIC-SIMPLE
# ########################
#
# --------------------------------------------
# is01
# Ode comp: 0.5918 (triads)
# ----------------------------------------------
#
# --------------------------------------------
# is02
# Ode comp: 0.5205 (triads)
# ----------------------------------------------
#
# --------------------------------------------
# is04
# Ode comp: 0.5151 (triads)
# ----------------------------------------------
#
# --------------------------------------------
# is05
# Ode comp: 0.4717 (triads)
# ----------------------------------------------
#
# --------------------------------------------
# is06
# Ode comp: 0.5402 (triads)
# ----------------------------------------------
#
# --------------------------------------------
# is07
# Ode comp: 0.5491 (triads)
# ----------------------------------------------
#
# --------------------------------------------
# is08
# Ode comp: 0.4911 (triads)
# ----------------------------------------------
# ...

# %%
print("\n######################")
print("STROPHIC-ANTISTROPHIC")
print("########################")

for ode in song_scores_strophes:

    print('\n--------------------------------------------')
    print(f'\033[1;32m{ode}\033[0m')
    print(f'Ode comp: \033[1;32m{song_scores_strophes[ode]:.4f}\033[0m (strophes)')
    print('----------------------------------------------')
# Out:
# ######################
# STROPHIC-ANTISTROPHIC
# ########################
#
# --------------------------------------------
# is01
# Ode comp: 0.5362 (strophes)
# ----------------------------------------------
#
# --------------------------------------------
# is02
# Ode comp: 0.6171 (strophes)
# ----------------------------------------------
#
# --------------------------------------------
# is04
# Ode comp: 0.5393 (strophes)
# ----------------------------------------------
#
# --------------------------------------------
# is05
# Ode comp: 0.5514 (strophes)
# ----------------------------------------------
#
# --------------------------------------------
# is06
# Ode comp: 0.6331 (strophes)
# ----------------------------------------------
#
# --------------------------------------------
# is07
# Ode comp: 0.6311 (strophes)
# ----------------------------------------------
#
# --------------------------------------------
# ne01
# Ode comp: 0.5639 (strophes)
# ...

# %% [markdown]
# We want to compare results for triadic-simple and for strophic-antistrophic responsion types.
#
# Hence, for the tests we run the stats on their intersection ode set `(tri & str)`, consisting of the 33 fully triadic odes.
#
# We need to make all baselines twice (see separate nb), then calculate all 10 000 statistics and do the four tests twice.

# %% [markdown]
# ## Triadic-simple

# %% [markdown]
# ### Observed distribution (Pindar)

# %% [markdown]
# Let's start with $T_{pos}$ for the Pindar corpus of 33 fully-triadic odes, using triadic-simple responsion. We reprint the score here for clarity.

# %%
print(f'\033[1;33mTRIADIC-SIMPLE RESPONSION: FULLY-TRIADIC ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_obs_pos: \033[1;32m{T_obs_pos_fully_triadic:.4f}\033[0m')
print(f'Number of variables: {total_fully_triadic}')
# Out:
# TRIADIC-SIMPLE RESPONSION: FULLY-TRIADIC ODES
#
# Pindar: T_obs_pos: 0.5276
# Number of variables: 9538

# %%
print(f'\033[1;33mTRIADIC-SIMPLE RESPONSION: FULLY-TRIADIC ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_obs_song: \033[1;32m{T_obs_song_fully_triadic_triads:.4f}\033[0m')
# Out:
# TRIADIC-SIMPLE RESPONSION: FULLY-TRIADIC ODES
#
# Pindar: T_obs_song: 0.5281

# %% [markdown]
# ### Expected distributions (baselines)

# %% [markdown]
# The 10 000 expected statistics for both prose and lyric for the fully-triadic set of odes using the triadic-simple responsion type are calculated with the script `scripts/calculate_expected.py`. Information about the results is provided in the log below.

# %%
'''
Tue May  5 06:19:53 2026: Completed expected statistics for triads in 5569.92 seconds with 11 workers and chunk size 100.

Completed: 0 chunks from cache, 100 chunks computed (10000 total iterations)
Expected statistics calculated in 5569.92 seconds with 11 workers and chunk size 100.

First sample in each test statistic series:

T_pos_prose_list: 0.524
T_song_prose_list: 0.524
T_pos_lyric_list: 0.517
T_song_lyric_list: 0.515

Lyric baseline composition (aggregated) for responsion type triads:
  total_lines: 30020000
  pindar_lines: 29820000
  external_lines: 200000
  prose_lines: 0
  unaltered_lines: 27976451
  trimmed_lines: 2043549
  padded_lines: 0
  paired_fallbacks: 0
  prose_fallback_details: []

'''
# Out:
# '\nTue May  5 06:19:53 2026: Completed expected statistics for triads in 5569.92 seconds with 11 workers and chunk size 100.\n\nCompleted: 0 chunks from cache, 100 chunks computed (10000 total iterations)\nExpected statistics calculated in 5569.92 seconds with 11 workers and chunk size 100.\n\nFirst sample in each test statistic series:\n\nT_pos_prose_list: 0.524\nT_song_prose_list: 0.524\nT_pos_lyric_list: 0.517\nT_song_lyric_list: 0.515\n\nLyric baseline composition (aggregated) for responsion type triads:\n  total_lines: 30020000\n  pindar_lines: 29820000\n  external_lines: 200000\n  prose_lines: 0\n  unaltered_lines: 27976451\n  trimmed_lines: 2043549\n  padded_lines: 0\n  paired_fallbacks: 0\n  prose_fallback_details: []\n\n'

# %% [markdown]
# As expected, *T_pos is slightly lower than T_song* (since longer songs tend to more strictions on responsion) and *the lyric baselines are slightly lower than the prose* (because lyric is also more constrained than prose).
#
# Now let's do the Monte Carlo simulation, i.e. load the lists of test statstics for n randomizations/permutations of the corpus and calculate means.

# %%
import numpy as np
import pickle

pickle_input_triads = ROOT / "data/cache/test_statistics_triads.pkl"

with open(pickle_input_triads, "rb") as f:
    T_exp_pos_prose_list, T_exp_song_prose_list, T_exp_pos_lyric_list, T_exp_song_lyric_list, lyric_stats_summary = pickle.load(f)

# Print mean of each list as .3f list to verify
print("Mean(T_exp_pos_prose_list):", f"{np.mean(T_exp_pos_prose_list):.4f}")
print("Mean(T_exp_song_prose_list):", f"{np.mean(T_exp_song_prose_list):.4f}")
print("Mean(T_exp_pos_lyric_list):", f"{np.mean(T_exp_pos_lyric_list):.4f}")
print("Mean(T_exp_song_lyric_list):", f"{np.mean(T_exp_song_lyric_list):.4f}")

# Compare with T_obs
print("\nComparison with observed T values:")
print(f"T_obs_pos_triads: {T_obs_pos_fully_triadic:.4f}")
print(f"T_obs_song_triads: {T_obs_song_fully_triadic_triads:.4f}")

if lyric_stats_summary:
    print("\nLyric baseline composition (aggregated):")
    for k, v in lyric_stats_summary.items():
        print(f"  {k}: {v}")
# Out:
# Mean(T_exp_pos_prose_list): 0.5101
# Mean(T_exp_song_prose_list): 0.5101
# Mean(T_exp_pos_lyric_list): 0.5133
# Mean(T_exp_song_lyric_list): 0.5121
#
# Comparison with observed T values:
# T_obs_pos_triads: 0.5276
# T_obs_song_triads: 0.5281
#
# Lyric baseline composition (aggregated):
#   total_lines: 30020000
#   pindar_lines: 29820000
#   external_lines: 200000
#   prose_lines: 0
#   unaltered_lines: 27976451
#   trimmed_lines: 2043549
#   padded_lines: 0
#   paired_fallbacks: 0
#   prose_fallback_details: []

# %% [markdown]
# ## Strophic-antistrophic

# %% [markdown]
# ### Observed distribution

# %% [markdown]
# Here is $T_{pos}$ for the Pindar corpus of 33 fully-triadic odes, using *strophic-antistrophic* responsion. We reprint the score here for clarity.

# %%
print(f'\033[1;33mSTROPHIC-ANTISTROPHIC RESPONSION: FULLY-TRIADIC ODES\033[0m\n')
print(f'\033[33mPindar\033[0m: T_obs_pos: \033[1;32m{T_obs_pos_fully_triadic_strophes:.4f}\033[0m')
print(f'\033[33mPindar\033[0m: T_obs_song: \033[1;32m{T_obs_song_fully_triadic_strophes:.4f}\033[0m')
print(f'Number of variables: {total_fully_triadic_strophic}')
# Out:
# STROPHIC-ANTISTROPHIC RESPONSION: FULLY-TRIADIC ODES
#
# Pindar: T_obs_pos: 0.5566
# Pindar: T_obs_song: 0.5593
# Number of variables: 3202

# %% [markdown]
# ### Expected distribution

# %%
'''
Mon May  4 23:47:52 2026: Completed expected statistics for strophes in 3847.99 seconds with 11 workers and chunk size 100.

Completed: 0 chunks from cache, 100 chunks computed (10000 total iterations)
Expected statistics calculated in 3847.99 seconds with 11 workers and chunk size 100.

First sample in each test statistic series:

T_pos_prose_strophes_list: 0.518
T_song_prose_strophes_list: 0.520
T_pos_lyric_strophes_list: 0.540
T_song_lyric_strophes_list: 0.540

Lyric baseline composition (aggregated) for responsion type strophes:
  total_lines: 20120000
  pindar_lines: 19640000
  external_lines: 480000
  prose_lines: 0
  unaltered_lines: 16615160
  trimmed_lines: 3474840
  padded_lines: 30000
  paired_fallbacks: 0
  prose_fallback_details: []

'''
# Out:
# '\nMon May  4 23:47:52 2026: Completed expected statistics for strophes in 3847.99 seconds with 11 workers and chunk size 100.\n\nCompleted: 0 chunks from cache, 100 chunks computed (10000 total iterations)\nExpected statistics calculated in 3847.99 seconds with 11 workers and chunk size 100.\n\nFirst sample in each test statistic series:\n\nT_pos_prose_strophes_list: 0.518\nT_song_prose_strophes_list: 0.520\nT_pos_lyric_strophes_list: 0.540\nT_song_lyric_strophes_list: 0.540\n\nLyric baseline composition (aggregated) for responsion type strophes:\n  total_lines: 20120000\n  pindar_lines: 19640000\n  external_lines: 480000\n  prose_lines: 0\n  unaltered_lines: 16615160\n  trimmed_lines: 3474840\n  padded_lines: 30000\n  paired_fallbacks: 0\n  prose_fallback_details: []\n\n'

# %%
import numpy as np
import pickle

pickle_input_strophes = ROOT / "data/cache/test_statistics_strophes.pkl"

with open(pickle_input_strophes, "rb") as f:
    T_exp_pos_prose_strophes_list, T_exp_song_prose_strophes_list, T_exp_pos_lyric_strophes_list, T_exp_song_lyric_strophes_list, lyric_stats_summary = pickle.load(f)

# Print mean of each list as .3f list to verify
print("Mean(T_exp_pos_prose_strophes_list):", f"{np.mean(T_exp_pos_prose_strophes_list):.4f}")
print("Mean(T_exp_song_prose_strophes_list):", f"{np.mean(T_exp_song_prose_strophes_list):.4f}")
print("Mean(T_exp_pos_lyric_strophes_list):", f"{np.mean(T_exp_pos_lyric_strophes_list):.4f}")
print("Mean(T_exp_song_lyric_strophes_list):", f"{np.mean(T_exp_song_lyric_strophes_list):.4f}")

# Compare with T_obs
print("\nComparison with observed T values:")
print(f"T_obs_pos_strophes: {T_obs_pos_fully_triadic_strophes:.4f}")
print(f"T_obs_song_strophes: {T_obs_song_fully_triadic_strophes:.4f}")

if lyric_stats_summary:
    print("\nLyric baseline composition (aggregated):")
    for k, v in lyric_stats_summary.items():
        print(f"  {k}: {v}")
# Out:
# Mean(T_exp_pos_prose_strophes_list): 0.5137
# Mean(T_exp_song_prose_strophes_list): 0.5160
# Mean(T_exp_pos_lyric_strophes_list): 0.5337
# Mean(T_exp_song_lyric_strophes_list): 0.5348
#
# Comparison with observed T values:
# T_obs_pos_strophes: 0.5566
# T_obs_song_strophes: 0.5593
#
# Lyric baseline composition (aggregated):
#   total_lines: 20120000
#   pindar_lines: 19640000
#   external_lines: 480000
#   prose_lines: 0
#   unaltered_lines: 16615160
#   trimmed_lines: 3474840
#   padded_lines: 30000
#   paired_fallbacks: 0
#   prose_fallback_details: []

# %%
# first five entries in each expected list

print("First 5 entries in T_exp_pos_prose_strophes_list:", [f"{x:.4f}" for x in T_exp_pos_prose_strophes_list[:5]])
print("First 5 entries in T_exp_song_prose_strophes_list:", [f"{x:.4f}" for x in T_exp_song_prose_strophes_list[:5]])
print("First 5 entries in T_exp_pos_lyric_strophes_list:", [f"{x:.4f}" for x in T_exp_pos_lyric_strophes_list[:5]])
print("First 5 entries in T_exp_song_lyric_strophes_list:", [f"{x:.4f}" for x in T_exp_song_lyric_strophes_list[:5]])
# Out:
# First 5 entries in T_exp_pos_prose_strophes_list: ['0.5177', '0.5166', '0.5128', '0.5312', '0.5213']
# First 5 entries in T_exp_song_prose_strophes_list: ['0.5198', '0.5193', '0.5152', '0.5341', '0.5244']
# First 5 entries in T_exp_pos_lyric_strophes_list: ['0.5399', '0.5320', '0.5323', '0.5341', '0.5279']
# First 5 entries in T_exp_song_lyric_strophes_list: ['0.5397', '0.5329', '0.5340', '0.5343', '0.5282']

# %% [markdown]
# # Significance tests

# %% [markdown]
# ## Triadic-simple

# %% [markdown]
# ### One-sided permutation test

# %% [markdown]
# We perform a one-sided permutation test, because the hypothesis is directional, i.e. we do not expect the test statistic to be symmetric around 0. (NB: A two-sided permutation test has the absolute sizes $|T_{E, i}| \ge |T_{\text{O}}|$)
#
# Let $T_{\text{O}} =$ observed statistic (Pindar)
# and $\{T_{E, 1}, \dots, T_{E, 10000}\} =$ baseline values
#
# Compute, for each list in T_pos_prose_list, T_song_prose_list, T_pos_lyric_list, T_song_lyric_list:
#
# $$p = \frac{1 + \|\{i: T_{E, i} \ge T_{\text{O}}\}\|}{1 + 10000}$$

# %%
'''
Two observed test statistics: 
T_obs_pos_fully_triadic, 
T_obs_song_fully_triadic_triads

Four lists of expected test statistics:
T_exp_pos_prose_list, 
T_exp_song_prose_list, 
T_exp_pos_lyric_list,
T_exp_song_lyric_list

T_obs_pos_fully_triadic will be compared to entries in T_exp_pos_prose_list and T_exp_pos_lyric_list
T_obs_song_fully_triadic_triads will be compared to entries in T_exp_song_prose_list and T_exp_song_lyric_list
'''

import numpy as np

def permutation_p_value(T_obs, baseline):
    baseline_arr = np.asarray(baseline)
    ge_count = np.sum(baseline_arr >= T_obs) # ge = greater than or equal to
    return (1 + ge_count) / (1 + baseline_arr.size) # convention to add 1 to numerator and denominator to avoid zero p-value (source: https://en.wikipedia.org/wiki/P-value#Permutation_tests)


p_pos_prose = permutation_p_value(T_obs_pos_fully_triadic, T_exp_pos_prose_list)
p_pos_lyric = permutation_p_value(T_obs_pos_fully_triadic, T_exp_pos_lyric_list)

p_song_prose = permutation_p_value(T_obs_song_fully_triadic_triads, T_exp_song_prose_list)
p_song_lyric = permutation_p_value(T_obs_song_fully_triadic_triads, T_exp_song_lyric_list)

print(f"p_pos_prose (triads vs prose baseline): {p_pos_prose:.4f}")
print(f"p_pos_lyric (triads vs lyric baseline): {p_pos_lyric:.4f}")
print(f"p_song_prose (triads-song vs prose baseline): {p_song_prose:.4f}")
print(f"p_song_lyric (triads-song vs lyric baseline): {p_song_lyric:.4f}")
# Out:
# p_pos_prose (triads vs prose baseline): 0.0029
# p_pos_lyric (triads vs lyric baseline): 0.0018
# p_song_prose (triads-song vs prose baseline): 0.0034
# p_song_lyric (triads-song vs lyric baseline): 0.0013

# %% [markdown]
# From more to less significant:
# `p_song_lyric` < `p_song_prose` < `p_pos_prose` < `p_pos_lyric`
#
# All four p-values are below 0.01, which is strong evidence that the observed responsion patterns in Pindar are not due to chance, and that the constraints of lyric and prose do not fully explain the observed patterns.
#
# 1. **The song-based statistics are clearly more significant than the position-based statistic**,
#     - which suggests that Pindar's shorter songs were more responding.
# 2. **Testing against lyric is harder (= a better test) than testing against prose**,
#     - which is expected.

# %%
import matplotlib.pyplot as plt

from responsio_accentuum import apply_bw_journal_style

apply_bw_journal_style()

labels = [
    "T_pos vs prose",
    "T_pos vs lyric",
    "T_song vs prose",
    "T_song vs lyric",
]
values = [p_pos_prose, p_pos_lyric, p_song_prose, p_song_lyric]
colors = ["#4c72b0", "#55a868", "#c44e52", "#8172b3"]

fig, ax = plt.subplots(figsize=(7, 4))
bars = ax.bar(labels, values, color=colors)
#ax.axhline(0.05, color="black", linestyle="--", linewidth=1, label="alpha = 0.05")
ax.axhline(0.01, color="grey", linestyle="--", linewidth=1, label="alpha = 0.01")
ax.set_ylabel("p-value")
ax.set_title("Permutation test p-values (33 fully-triadic odes, triadic-simple responsion type)")
ax.set_ylim(0, 0.015)
ax.grid(axis="y", linestyle=":", alpha=0.5)

for bar, val in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, val + 0.005, f"{val:.4f}", ha="center", va="bottom", fontsize=9)

ax.legend(frameon=False)
plt.tight_layout()

# %% [markdown]
# ### Effect size

# %% [markdown]
# We can also measure the effect size by computing the z-score of the observed statistic relative to the baseline distribution:
#
# $$z_{\text{emp}} = \frac{T_{\text{obs}} - \mu_0}{\sigma_0}$$
#
# Source: https://en.wikipedia.org/wiki/Permutation_test#One-sided_permutation_test

# %%
import numpy as np

def z_score(T_obs, baseline):
    arr = np.asarray(baseline, dtype=float)
    mu = arr.mean()
    sigma = arr.std(ddof=0)
    return (float(T_obs) - mu) / sigma if sigma != 0 else np.nan

z_pos_prose = z_score(T_obs_pos_fully_triadic, T_exp_pos_prose_list)
z_pos_lyric = z_score(T_obs_pos_fully_triadic, T_exp_pos_lyric_list)

z_song_prose = z_score(T_obs_song_fully_triadic_triads, T_exp_song_prose_list)
z_song_lyric = z_score(T_obs_song_fully_triadic_triads, T_exp_song_lyric_list)

print(f"z_pos_prose (triads vs prose baseline): {z_pos_prose:.3f}")
print(f"z_pos_lyric (triads vs lyric baseline): {z_pos_lyric:.3f}")
print(f"z_song_prose (triads-song vs prose baseline): {z_song_prose:.3f}")
print(f"z_song_lyric (triads-song vs lyric baseline): {z_song_lyric:.3f}")
# Out:
# z_pos_prose (triads vs prose baseline): 2.778
# z_pos_lyric (triads vs lyric baseline): 3.010
# z_song_prose (triads-song vs prose baseline): 2.737
# z_song_lyric (triads-song vs lyric baseline): 3.157

# %% [markdown]
# ### Histograms

# %% [markdown]
# It can be interesting to plot the observed distribution and the means of the two baseline distributions as histograms with the bins of normalized compatibility scores.

# %%
import numpy as np
import matplotlib.pyplot as plt

from responsio_accentuum import apply_bw_journal_style

apply_bw_journal_style()

universal_x_label = "Test statistic"
universal_y_label = "Density of expected statistics"

fig, axes = plt.subplots(2, 2, figsize=(10, 6), sharey=True)

# --- compute global x-limits across all datasets + observed values ---
all_arrays = [
    np.asarray(T_exp_pos_prose_list, dtype=float),
    np.asarray(T_exp_pos_lyric_list, dtype=float),
    np.asarray(T_exp_song_prose_list, dtype=float),
    np.asarray(T_exp_song_lyric_list, dtype=float),
]

all_obs = [
    float(T_obs_pos_fully_triadic),
    float(T_obs_song_fully_triadic_triads),
]

xmin = min(np.min(a) for a in all_arrays)
xmax = max(np.max(a) for a in all_arrays)

xmin = min(xmin, min(all_obs))
xmax = max(xmax, max(all_obs))

# --- compute alpha = 0.01 critical values ---
alpha = 0.01

crit_pos_prose = np.quantile(
    np.asarray(T_exp_pos_prose_list, dtype=float),
    1 - alpha,
)

crit_pos_lyric = np.quantile(
    np.asarray(T_exp_pos_lyric_list, dtype=float),
    1 - alpha,
)

crit_song_prose = np.quantile(
    np.asarray(T_exp_song_prose_list, dtype=float),
    1 - alpha,
)

crit_song_lyric = np.quantile(
    np.asarray(T_exp_song_lyric_list, dtype=float),
    1 - alpha,
)

# --- histogram styling ---
hist_kwargs = dict(
    bins=20,
    density=True,
    facecolor="white",
    edgecolor="black",
    hatch="///",
    linewidth=0.8,
)

# --- TOP LEFT ---
arr = np.asarray(T_exp_pos_prose_list, dtype=float)
obs = float(T_obs_pos_fully_triadic)

axes[0, 0].hist(
    arr,
    **hist_kwargs,
)

axes[0, 0].axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, pos}$ (Pindar), " + f"p-value = {p_pos_prose:.3f}",
)

axes[0, 0].axvline(
    crit_pos_prose,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

axes[0, 0].set_title(r"$T_{pos}$ with prose baseline")
axes[0, 0].set_xlabel(universal_x_label)
axes[0, 0].set_ylabel(universal_y_label)

axes[0, 0].legend(
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
)

# --- TOP RIGHT ---
arr = np.asarray(T_exp_pos_lyric_list, dtype=float)
obs = float(T_obs_pos_fully_triadic)

axes[0, 1].hist(
    arr,
    **hist_kwargs,
)

axes[0, 1].axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, pos}$ (Pindar), " + f"p-value = {p_pos_lyric:.3f}",
)

axes[0, 1].axvline(
    crit_pos_lyric,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

axes[0, 1].set_title(r"$T_{pos}$ with lyric baseline")
axes[0, 1].set_xlabel(universal_x_label)
axes[0, 1].set_ylabel(universal_y_label)

axes[0, 1].legend(
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
)

# --- BOTTOM LEFT ---
arr = np.asarray(T_exp_song_prose_list, dtype=float)
obs = float(T_obs_song_fully_triadic_triads)

axes[1, 0].hist(
    arr,
    **hist_kwargs,
)

axes[1, 0].axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, song}$ (Pindar), " + f"p-value = {p_song_prose:.3f}",
)

axes[1, 0].axvline(
    crit_song_prose,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

axes[1, 0].set_title(r"$T_{song}$ with prose baseline")
axes[1, 0].set_xlabel(universal_x_label)
axes[1, 0].set_ylabel(universal_y_label)

axes[1, 0].legend(
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
)

# --- BOTTOM RIGHT ---
arr = np.asarray(T_exp_song_lyric_list, dtype=float)
obs = float(T_obs_song_fully_triadic_triads)

axes[1, 1].hist(
    arr,
    **hist_kwargs,
)

axes[1, 1].axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, song}$ (Pindar), " + f"p-value = {p_song_lyric:.3f}",
)

axes[1, 1].axvline(
    crit_song_lyric,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

axes[1, 1].set_title(r"$T_{song}$ with lyric baselines")
axes[1, 1].set_xlabel(universal_x_label)
axes[1, 1].set_ylabel(universal_y_label)

axes[1, 1].legend(
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
)

# --- enforce identical x-limits across all subplots ---
for ax in axes.flat:
    ax.set_xlim(xmin, xmax)

plt.tight_layout()

#plt.savefig(ROOT / "media" / "figures" / "perm" / "perm_triadic_simple.eps")
#plt.savefig(ROOT / "media" / "figures" / "perm" / "perm_triadic_simple.png",dpi=600)

plt.show()

# %% [markdown]
# For the article, we take one of the plots as an example (the worst performing one).

# %%
import numpy as np
import matplotlib.pyplot as plt

from responsio_accentuum import apply_bw_journal_style

apply_bw_journal_style()

universal_x_label = "Test statistic"
universal_y_label = "Density of expected statistics"

fig, ax = plt.subplots(figsize=(6.5, 4))

arr = np.asarray(T_exp_song_prose_list, dtype=float)
obs = float(T_obs_song_fully_triadic_triads)
expected_mean = float(np.mean(arr))
expected_std = float(np.std(arr, ddof=0))
z_score_value = (obs - expected_mean) / expected_std
alpha = 0.01
crit_song_prose = np.quantile(arr, 1 - alpha)
sigma_endpoint = expected_mean + expected_std

xmin = 0.49
xmax = max(np.max(arr), obs, expected_mean, sigma_endpoint, crit_song_prose)
xpad = (xmax - xmin) * 0.05
xmax += xpad

hist_kwargs = dict(
    bins=20,
    density=True,
    facecolor="white",
    edgecolor="black",
    linewidth=0.8,
)

ax.hist(
    arr,
    **hist_kwargs,
)

mean_line = ax.axvline(
    expected_mean,
    linestyle="-",
    linewidth=1.5,
    label=rf"$\mu = {expected_mean:.1g}$",
)

obs_line = ax.axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, song}$ (Pindar), " + f"p-value = {p_song_prose:.2g}",
)

crit_line = ax.axvline(
    crit_song_prose,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

ax.set_title(r"$T_{song}$ with prose baseline")
ax.set_xlabel(universal_x_label)
ax.set_ylabel(universal_y_label)
ax.set_xlim(xmin, xmax)

legend_items = sorted(
    [
        (expected_mean, mean_line),
        (obs, obs_line),
        (crit_song_prose, crit_line),
    ],
    key=lambda item: item[0],
)
legend_handles = [handle for _, handle in legend_items]
legend_labels = [handle.get_label() for handle in legend_handles]
ax.legend(
    legend_handles,
    legend_labels,
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
)

# Finalize the axes geometry before measuring TeX objects. If tight_layout runs
# after measurement, display-space centers no longer line up with data-space text.
plt.tight_layout()
fig.canvas.draw()

brace_fontsize = plt.rcParams["font.size"]
brace_label_offset = ax.get_ylim()[1] * 0.045

def add_overbrace(x0, x1, y, label):
    x0, x1 = sorted((x0, x1))
    x0_px = ax.transData.transform((x0, y))[0]
    x1_px = ax.transData.transform((x1, y))[0]
    brace_width_pt = abs(x1_px - x0_px) * 72 / fig.dpi

    brace = ax.text(
        x0,
        y,
        rf"$\boldmath\overbrace{{\rule{{{brace_width_pt:.2f}pt}}{{0pt}}}}$",
        ha="left",
        va="bottom",
        fontsize=brace_fontsize,
        usetex=True,
    )

    fig.canvas.draw()
    bbox = brace.get_window_extent(renderer=fig.canvas.get_renderer())
    label_x = ax.transData.inverted().transform((bbox.x0 + bbox.width / 2, 0))[0]
    ax.text(
        label_x,
        y + brace_label_offset,
        label,
        ha="center",
        va="bottom",
        fontsize=brace_fontsize,
    )

add_overbrace(expected_mean, obs, ax.get_ylim()[1] * 0.82, f"z-score = {z_score_value:.2g}σ")
add_overbrace(expected_mean, sigma_endpoint, ax.get_ylim()[1] * 0.68, "σ")

plt.savefig(ROOT / "media" / "figures" / "perm" / "perm_triadic_simple_example.eps")
plt.savefig(ROOT / "media" / "figures" / "perm" / "perm_triadic_simple_example.png", dpi=600)

plt.show()
# Out:
# The PS backend determines usetex status solely based on rcParams['text.usetex'] and does not support having usetex=True only for some elements; this element will thus be rendered as if usetex=False.
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %% [markdown]
# ## Strophic-antistrophic

# %% [markdown]
# ### One-sided permutation tests

# %%
'''
Two observed test statistics: 
T_obs_pos_fully_triadic_strophes, 
T_obs_song_fully_triadic_strophes

Four lists of expected test statistics:
T_exp_pos_prose_strophes_list, 
T_exp_song_prose_strophes_list, 
T_exp_pos_lyric_strophes_list,
T_exp_song_lyric_strophes_list

T_obs_pos_fully_triadic_strophes will be compared to entries in T_exp_pos_prose_strophes_list and T_exp_pos_lyric_strophes_list
T_obs_song_fully_triadic_strophes will be compared to entries in T_exp_song_prose_strophes_list and T_exp_song_lyric_strophes_list
'''

import numpy as np

def permutation_p_value(T_obs, baseline):
    baseline_arr = np.asarray(baseline)
    ge_count = np.sum(baseline_arr >= T_obs) # ge = greater than or equal to
    return (1 + ge_count) / (1 + baseline_arr.size) # convention to add 1 to numerator and denominator to avoid zero p-value (source: https://en.wikipedia.org/wiki/P-value#Permutation_tests)


p_pos_prose_strophic_antistrophic = permutation_p_value(T_obs_pos_fully_triadic_strophes, T_exp_pos_prose_strophes_list)
p_pos_lyric_strophic_antistrophic = permutation_p_value(T_obs_pos_fully_triadic_strophes, T_exp_pos_lyric_strophes_list)

p_song_prose_strophic_antistrophic = permutation_p_value(T_obs_song_fully_triadic_strophes, T_exp_song_prose_strophes_list)
p_song_lyric_strophic_antistrophic = permutation_p_value(T_obs_song_fully_triadic_strophes, T_exp_song_lyric_strophes_list)

print(f"p-value by-position prose-baseline strophic-antistrophic responsion type: \t\033[92m{p_pos_prose_strophic_antistrophic:.5f}\033[0m")
print(f"p-value by-position lyric-baseline strophic-antistrophic responsion type: \t\033[92m{p_pos_lyric_strophic_antistrophic:.5f}\033[0m")
print(f"p-value by-song prose-baseline strophic-antistrophic responsion type: \t\t\033[92m{p_song_prose_strophic_antistrophic:.5f}\033[0m")
print(f"p-value by-song lyric-baseline strophic-antistrophic responsion type: \t\t\033[92m{p_song_lyric_strophic_antistrophic:.5f}\033[0m")
# Out:
# p-value by-position prose-baseline strophic-antistrophic responsion type: 	0.00010
# p-value by-position lyric-baseline strophic-antistrophic responsion type: 	0.00020
# p-value by-song prose-baseline strophic-antistrophic responsion type: 		0.00010
# p-value by-song lyric-baseline strophic-antistrophic responsion type: 		0.00020

# %% [markdown]
# ### Effect size

# %%
import numpy as np

def z_score(T_obs, baseline):
    arr = np.asarray(baseline, dtype=float)
    mu = arr.mean()
    sigma = arr.std(ddof=0)
    return (float(T_obs) - mu) / sigma if sigma != 0 else np.nan

z_pos_prose_strophic_antistrophic = z_score(T_obs_pos_fully_triadic_strophes, T_exp_pos_prose_strophes_list)
z_pos_lyric_strophic_antistrophic = z_score(T_obs_pos_fully_triadic_strophes, T_exp_pos_lyric_strophes_list)

z_song_prose_strophic_antistrophic = z_score(T_obs_song_fully_triadic_strophes, T_exp_song_prose_strophes_list)
z_song_lyric_strophic_antistrophic = z_score(T_obs_song_fully_triadic_strophes, T_exp_song_lyric_strophes_list)

print(f"z_pos_prose_strophic_antistrophic: \t\033[92m{z_pos_prose_strophic_antistrophic:.3f}\033[0m")
print(f"z_pos_lyric_strophic_antistrophic: \t\033[92m{z_pos_lyric_strophic_antistrophic:.3f}\033[0m")
print(f"z_song_prose_strophic_antistrophic: \t\033[92m{z_song_prose_strophic_antistrophic:.3f}\033[0m")
print(f"z_song_lyric_strophic_antistrophic: \t\033[92m{z_song_lyric_strophic_antistrophic:.3f}\033[0m")
# Out:
# z_pos_prose_strophic_antistrophic: 	6.340
# z_pos_lyric_strophic_antistrophic: 	3.910
# z_song_prose_strophic_antistrophic: 	6.125
# z_song_lyric_strophic_antistrophic: 	3.958

# %% [markdown]
# ### Histograms

# %%
import numpy as np
import matplotlib.pyplot as plt

from responsio_accentuum import apply_bw_journal_style

apply_bw_journal_style()

universal_x_label = "Test statistic"
universal_y_label = "Density of expected statistics"

fig, axes = plt.subplots(2, 2, figsize=(10, 6), sharey=True)

# --- compute global x-limits across all datasets + observed values ---
all_arrays = [
    np.asarray(T_exp_pos_prose_strophes_list, dtype=float),
    np.asarray(T_exp_pos_lyric_strophes_list, dtype=float),
    np.asarray(T_exp_song_prose_strophes_list, dtype=float),
    np.asarray(T_exp_song_lyric_strophes_list, dtype=float),
]

all_obs = [
    float(T_obs_pos_fully_triadic_strophes),
    float(T_obs_song_fully_triadic_strophes),
]

xmin = min(np.min(a) for a in all_arrays)
xmax = max(np.max(a) for a in all_arrays)

xmin = min(xmin, min(all_obs))
xmax = max(xmax, max(all_obs))

# --- compute alpha = 0.01 critical values ---
alpha = 0.01

crit_pos_prose = np.quantile(
    np.asarray(T_exp_pos_prose_strophes_list, dtype=float),
    1 - alpha,
)

crit_pos_lyric = np.quantile(
    np.asarray(T_exp_pos_lyric_strophes_list, dtype=float),
    1 - alpha,
)

crit_song_prose = np.quantile(
    np.asarray(T_exp_song_prose_strophes_list, dtype=float),
    1 - alpha,
)

crit_song_lyric = np.quantile(
    np.asarray(T_exp_song_lyric_strophes_list, dtype=float),
    1 - alpha,
)

# --- histogram styling ---
hist_kwargs = dict(
    bins=20,
    density=True,
    facecolor="white",
    edgecolor="black",
#    hatch="///",
    linewidth=0.8,
)

# --- TOP LEFT ---
arr = np.asarray(T_exp_pos_prose_strophes_list, dtype=float)
obs = float(T_obs_pos_fully_triadic_strophes)

axes[0, 0].hist(
    arr,
    **hist_kwargs,
)

axes[0, 0].axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, pos}$ (Pindar), " + f"p-value = {p_pos_prose_strophic_antistrophic:.3f}",
)

axes[0, 0].axvline(
    crit_pos_prose,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

axes[0, 0].set_title(r"$T_{pos}$ vs prose baseline")
axes[0, 0].set_xlabel(universal_x_label)
axes[0, 0].set_ylabel(universal_y_label)

axes[0, 0].legend(
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
    loc="upper left",
)

# --- TOP RIGHT ---
arr = np.asarray(T_exp_pos_lyric_strophes_list, dtype=float)
obs = float(T_obs_pos_fully_triadic_strophes)

axes[0, 1].hist(
    arr,
    **hist_kwargs,
)

axes[0, 1].axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, pos}$ (Pindar), " + f"p-value = {p_pos_lyric_strophic_antistrophic:.3f}",
)

axes[0, 1].axvline(
    crit_pos_lyric,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

axes[0, 1].set_title(r"$T_{pos}$ vs lyric baseline")
axes[0, 1].set_xlabel(universal_x_label)
axes[0, 1].set_ylabel(universal_y_label)

axes[0, 1].legend(
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
    loc="upper left",
)

# --- BOTTOM LEFT ---
arr = np.asarray(T_exp_song_prose_strophes_list, dtype=float)
obs = float(T_obs_song_fully_triadic_strophes)

axes[1, 0].hist(
    arr,
    **hist_kwargs,
)

axes[1, 0].axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, song}$ (Pindar), " + f"p-value = {p_song_prose_strophic_antistrophic:.3f}",
)

axes[1, 0].axvline(
    crit_song_prose,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

axes[1, 0].set_title(r"$T_{song}$ vs prose baseline")
axes[1, 0].set_xlabel(universal_x_label)
axes[1, 0].set_ylabel(universal_y_label)

axes[1, 0].legend(
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
    loc="upper left",
)

# --- BOTTOM RIGHT ---
arr = np.asarray(T_exp_song_lyric_strophes_list, dtype=float)
obs = float(T_obs_song_fully_triadic_strophes)

axes[1, 1].hist(
    arr,
    **hist_kwargs,
)

axes[1, 1].axvline(
    obs,
    linestyle="--",
    linewidth=2,
    label=r"$T_{obs, song}$ (Pindar), " + f"p-value = {p_song_lyric_strophic_antistrophic:.3f}",
)

axes[1, 1].axvline(
    crit_song_lyric,
    linestyle=":",
    linewidth=2,
    label=r"$\alpha = 0.01$",
)

axes[1, 1].set_title(r"$T_{song}$ vs lyric baseline")
axes[1, 1].set_xlabel(universal_x_label)
axes[1, 1].set_ylabel(universal_y_label)

axes[1, 1].legend(
    frameon=True,
    facecolor="white",
    edgecolor="black",
    framealpha=1.0,
    loc="upper left",
)

# --- enforce identical x-limits across all subplots ---
for ax in axes.flat:
    ax.set_xlim(xmin, xmax)

plt.tight_layout()

#plt.savefig(ROOT / "media" / "figures" / "perm" / "perm_strophic_antistrophic.eps")
#plt.savefig(ROOT / "media" / "figures" / "perm" / "perm_strophic_antistrophic.png", dpi=600)

plt.show()
