# %% [markdown]
# Get the score for the first line of the first Olympian ode:

# %%
from pathlib import Path
ROOT = Path.cwd().parent

from stats_comp import compatibility_canticum, compatibility_ratios_to_stats
from utils.utils import flatten_recursive

fractions = compatibility_canticum(ROOT / "data/compiled/extra/test_ol01.xml", "te01")
score = compatibility_ratios_to_stats(fractions)

print("Normalized score per syll:")
print(" ".join(str(frac) for frac in flatten_recursive(fractions)))

print(f"\nMean song score: {float(score)} (= {score})")
# Out:
# Normalized score per syll:
# 1 1/2 0 1/2 1 0 0 1/2 1/2 1/2 0 0 1/2 1/2 1/2
#
# Mean song score: 0.4 (= 2/5)
