# %% [markdown]
# # Prepare verse corpus for the responsion analysis

# %% [markdown]
# ## 1. Extraction

# %%
from src.extract import transform_tei

input_file = "data/source/01_olympia.xml"
output_file = "data/raw/01_olympia.xml"

transform_tei(input_file, output_file)
# Out:
# [WARNING] Canticum 2 has inconsistent strophe lengths: [20, 21, 20, 20, 20]
# [WARNING] Canticum 3 has inconsistent strophe lengths: [30, 15]
# [WARNING] Canticum 9 has inconsistent strophe lengths: [27, 28, 28, 28]

# %% [markdown]
# ## 2. Macronization

# %%
from src.macronize import macronize_xml
#from src.tidy import tidy_xml

input_file = "data/raw/ol01.xml"
output_file = "data/macronized/ol01_macronized.xml"

macronize_xml(input_file, output_file)
# Out:
# 100%|██████████| 120/120 [00:04<00:00, 25.80it/s]

# %% [markdown]
# ## 2a. Rule scansion

# %%
from src.scan import rule_scansion

input = "ἁνίκ' ἄγκυ_ρα^ν ποτὶ^ χαλκόγενυ^ν"
scanned = rule_scansion(input)
print(scanned)
input = "νυκτὶ^ κοινά_σαντες ὁδόν, Κρονί^δᾳ δὲ τˈρά^φεν Χίρωνι^ δῶκα^ν."
scanned = rule_scansion(input)
print(f"\n{scanned}")
input = "'Οὔ τί^ που οὗτος Ἀπόλλων, οὐδὲ μὰ_ν χαλκάρμα^τός ἐστι^ πόσι^ς"
scanned = rule_scansion(input)
print(f"\n{scanned}")
input = "εἰ μετάλλατόν τι^· καὶ ὡς τά^χος ὀτˈρύνει με τεύχειν να_ῒ^ πομπάν."
scanned = rule_scansion(input)
print(f"\n{scanned}")
# Out:
# {ἁ}{νί}[κ' ἄγ][κυ_][ρα^ν ]{πο}{τὶ^ }[χαλ]{κό}{γε}[νυ^ν]
#
# [νυκ]{τὶ^ }[κοι][νά_][σαν]{τε}{ς ὁ}[δόν, ]{Κρο}{νί^}[δᾳ ][δὲ τˈ]{ρά^}[φεν ]{Χί}[ρω]{νι^ }[δῶ][κα^ν.]
#
# ['Οὔ ]{τί^ }{που }[οὗ]{το}[ς Ἀ][πόλ][λω][ν, οὐ]{δὲ }[μὰ_ν ][χαλ][κάρ]{μα^}{τό}[ς ἐσ]{τι^ }{πό}[σι^ς]
#
# [εἰ ]{με}[τάλ]{λα}[τόν ]{τι^· }{καὶ }[ὡς ]{τά^}{χο}[ς ὀτˈ]{ρύ}[νει ]{με }[τεύ][χειν ][να_]{ῒ^ }[πομ][πάν.]

# %%
from src.scan import scan_xml

input_file = "data/raw/ol01.xml"
output_file = "data/scan/ol01.xml"
scan_xml(input_file, output_file, debug=False)
# Out:
# 120it [00:00, 671.42it/s]

# %% [markdown]
# ## 2b. Extract scansion from Hypotactic

# %%
from scan_ht import extract_strophic_syllables_from_html, create_tei_xml

html_file = "ht/pythians.html"

poems_dict = extract_strophic_syllables_from_html(html_file, debug=True)

tei_xml = create_tei_xml(poems_dict, title="Pythian Odes", prefix="py", output_file="data/scan/ht_pythians.xml")
# Out:
# Processing file: ht/pythians.html
# Found 12 poem divs
#
# Processing poem 1
# Found 15 strophe divs in poem 1
#   Strophe 1: type='Strophe', num='1'
#   Classes: ['strophe']
#     Processing as key: strophe_1
#     Found 7 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'selected']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 6 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='χρυ'
#           Span: classes=['syll', 'short'], content='σέ'
#           Span: classes=['syll', 'long'], content='α'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='φόρ'
#           Span: classes=['syll', 'long'], content='μιγξ,'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'short'], content='Ἀ'
#           Span: classes=['syll', 'long'], content='πόλ'
#           Span: classes=['syll', 'long', 'link'], content='λω'
#           Span: classes=['syll', 'long'], content='νος'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='καὶ'
#         Word 5: 5 sylls
#           Span: classes=['syll', 'short'], content='ἰ'
#           Span: classes=['syll', 'long'], content='ο'
#           Span: classes=['syll', 'short'], content='πλο'
#           Span: classes=['syll', 'short'], content='κά'
#           Span: classes=['syll', 'long', 'worddiv'], content='μων'
#       Final result: '[χρυ]{σέ}[α ][φόρ][μιγξ, ]{Ἀ}[πόλ][λω][νος ]{καὶ }{ἰ}[ο]{πλο}{κά}[μων]'
#       Extracted syllables: '[χρυ]{σέ}[α ][φόρ][μιγξ, ]{Ἀ}[πόλ][λω][νος ]{καὶ }{ἰ}[ο]{πλο}{κά}[μων]'
#       Child line 2: classes ['line', 'checked', 'selected']
#       Found 9 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='σύν'
#           Span: classes=['syll', 'short'], content='δι'
#           Span: classes=['syll', 'long'], content='κον'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='Μοι'
#           Span: classes=['syll', 'long'], content='σᾶν'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='κτέ'
#           Span: classes=['syll', 'short'], content='α'
#           Span: classes=['syll', 'long'], content='νον·'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long'], content='τᾶς'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='κού'
#           Span: classes=['syll', 'long', 'link'], content='ει'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'long'], content='μὲν'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='βά'
#           Span: classes=['syll', 'short'], content='σις,'
#         Word 8: 4 sylls
#           Span: classes=['syll', 'long'], content='ἀ'
#           Span: classes=['syll', 'short'], content='γλα'
#           Span: classes=['syll', 'short'], content='ΐ'
#           Span: classes=['syll', 'long'], content='ας'
#         Word 9: 2 sylls
#           Span: classes=['syll', 'long'], content='ἀρ'
#           Span: classes=['syll', 'long', 'context-menu-active', 'worddiv'], content='χά,'
#       Final result: '[σύν]{δι}[κον ][Μοι][σᾶν ]{κτέ}{α}[νον· ][τᾶς ]{ἀ}[κού][ει ][μὲν ]{βά}{σις, }[ἀ]{γλα}{ΐ}[ας ][ἀρ][χά,]'
#       Extracted syllables: '[σύν]{δι}[κον ][Μοι][σᾶν ]{κτέ}{α}[νον· ][τᾶς ]{ἀ}[κού][ει ][μὲν ]{βά}{σις, }[ἀ]{γλα}{ΐ}[ας ][ἀρ][χά,]'
#       Child line 3: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='πεί'
#           Span: classes=['syll', 'long'], content='θον'
#           Span: classes=['syll', 'long'], content='ται'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='δ᾽ἀ'
#           Span: classes=['syll', 'long'], content='οι'
#           Span: classes=['syll', 'long', 'link'], content='δοὶ'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='σά'
#           Span: classes=['syll', 'short'], content='μα'
#           Span: classes=['syll', 'long', 'worddiv'], content='σιν,'
#       Final result: '[πεί][θον][ται ]{δ᾽ἀ}[οι][δοὶ ][σά]{μα}[σιν,]'
#       Extracted syllables: '[πεί][θον][ται ]{δ᾽ἀ}[οι][δοὶ ][σά]{μα}[σιν,]'
#       Child line 4: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 5 sylls
#           Span: classes=['syll', 'long', 'link'], content='ἁ'
#           Span: classes=['syll', 'long'], content='γη'
#           Span: classes=['syll', 'short'], content='σι'
#           Span: classes=['syll', 'short'], content='χό'
#           Span: classes=['syll', 'long'], content='ρων'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='ὁ'
#           Span: classes=['syll', 'short'], content='πό'
#           Span: classes=['syll', 'long'], content='ταν'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'short', 'exception', 'link'], content='προ'
#           Span: classes=['syll', 'long'], content='οι'
#           Span: classes=['syll', 'short'], content='μί'
#           Span: classes=['syll', 'long'], content='ων'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='ἀμ'
#           Span: classes=['syll', 'short'], content='βο'
#           Span: classes=['syll', 'long'], content='λὰς'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='τεύ'
#           Span: classes=['syll', 'long'], content='χῃς'
#         Word 6: 6 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'short'], content='λε'
#           Span: classes=['syll', 'long'], content='λι'
#           Span: classes=['syll', 'short'], content='ζο'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='να.'
#       Final result: '[ἁ][γη]{σι}{χό}[ρων ]{ὁ}{πό}[ταν ]{προ}[οι]{μί}[ων ][ἀμ]{βο}[λὰς ][τεύ][χῃς ]{ἐ}{λε}[λι]{ζο}{μέ}[να.]'
#       Extracted syllables: '[ἁ][γη]{σι}{χό}[ρων ]{ὁ}{πό}[ταν ]{προ}[οι]{μί}[ων ][ἀμ]{βο}[λὰς ][τεύ][χῃς ]{ἐ}{λε}[λι]{ζο}{μέ}[να.]'
#       Child line 5: classes ['line', 'checked', 'fifth']
#       Found 5 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='καὶ'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='τὸν'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='αἰχ'
#           Span: classes=['syll', 'long', 'link'], content='μα'
#           Span: classes=['syll', 'long'], content='τὰν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='κε'
#           Span: classes=['syll', 'long'], content='ραυ'
#           Span: classes=['syll', 'long', 'link'], content='νὸν'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'long'], content='σβεν'
#           Span: classes=['syll', 'short'], content='νύ'
#           Span: classes=['syll', 'long', 'worddiv'], content='εις'
#       Final result: '[καὶ ]{τὸν }[αἰχ][μα][τὰν ]{κε}[ραυ][νὸν ][σβεν]{νύ}[εις]'
#       Extracted syllables: '[καὶ ]{τὸν }[αἰχ][μα][τὰν ]{κε}[ραυ][νὸν ][σβεν]{νύ}[εις]'
#       Child line 6: classes ['line', 'checked']
#       Found 11 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'long'], content='ἀ'
#           Span: classes=['syll', 'short'], content='ε'
#           Span: classes=['syll', 'short'], content='νά'
#           Span: classes=['syll', 'long'], content='ου'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='πυ'
#           Span: classes=['syll', 'short'], content='ρός.'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='εὕ'
#           Span: classes=['syll', 'long'], content='δει'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='δ᾽ἀ'
#           Span: classes=['syll', 'long'], content='νὰ'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='σκά'
#           Span: classes=['syll', 'long'], content='πτῳ'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='Δι'
#           Span: classes=['syll', 'short'], content='ὸς'
#         Word 7: 3 sylls
#           Span: classes=['syll', 'long'], content='αἰ'
#           Span: classes=['syll', 'short'], content='ε'
#           Span: classes=['syll', 'short'], content='τός,'
#         Word 8: 3 sylls
#           Span: classes=['syll', 'long'], content='ὠ'
#           Span: classes=['syll', 'long', 'unres', 'link'], content='κεῖ'
#           Span: classes=['syll', 'long'], content='αν'
#         Word 9: 2 sylls
#           Span: classes=['syll', 'short'], content='πτέ'
#           Span: classes=['syll', 'short'], content='ρυγʼ'
#         Word 10: 5 sylls
#           Span: classes=['syll', 'long'], content='ἀμ'
#           Span: classes=['syll', 'short'], content='φο'
#           Span: classes=['syll', 'short'], content='τέ'
#           Span: classes=['syll', 'long'], content='ρω'
#           Span: classes=['syll', 'long'], content='θεν'
#         Word 11: 3 sylls
#           Span: classes=['syll', 'short'], content='χα'
#           Span: classes=['syll', 'long'], content='λά'
#           Span: classes=['syll', 'long', 'link', 'worddiv'], content='ξαις,'
#       Final result: '[ἀ]{ε}{νά}[ου ]{πυ}{ρός. }[εὕ][δει ]{δ᾽ἀ}[νὰ ][σκά][πτῳ ]{Δι}{ὸς }[αἰ]{ε}{τός, }[ὠ][κεῖ][αν ]{πτέ}{ρυγʼ }[ἀμ]{φο}{τέ}[ρω][θεν ]{χα}[λά][ξαις,]'
#       Extracted syllables: '[ἀ]{ε}{νά}[ου ]{πυ}{ρός. }[εὕ][δει ]{δ᾽ἀ}[νὰ ][σκά][πτῳ ]{Δι}{ὸς }[αἰ]{ε}{τός, }[ὠ][κεῖ][αν ]{πτέ}{ρυγʼ }[ἀμ]{φο}{τέ}[ρω][θεν ]{χα}[λά][ξαις,]'
#     Total lines collected: 6
#   Strophe 2: type='Antistrophe', num='1'
#   Classes: ['strophe', 'antistrophe']
#     Processing as key: antistrophe_1
#     Found 7 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 6 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='ἀρ'
#           Span: classes=['syll', 'short'], content='χὸς'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='οἰ'
#           Span: classes=['syll', 'long', 'link'], content='ω'
#           Span: classes=['syll', 'long'], content='νῶν,'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'short'], content='κε'
#           Span: classes=['syll', 'long'], content='λαι'
#           Span: classes=['syll', 'long', 'link'], content='νῶ'
#           Span: classes=['syll', 'long'], content='πιν'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='δ᾽ἐ'
#           Span: classes=['syll', 'short'], content='πί'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long'], content='οἱ'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'short'], content='νε'
#           Span: classes=['syll', 'short'], content='φέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='λαν'
#       Final result: '[ἀρ]{χὸς }[οἰ][ω][νῶν, ]{κε}[λαι][νῶ][πιν ]{δ᾽ἐ}{πί }[οἱ ]{νε}{φέ}[λαν]'
#       Extracted syllables: '[ἀρ]{χὸς }[οἰ][ω][νῶν, ]{κε}[λαι][νῶ][πιν ]{δ᾽ἐ}{πί }[οἱ ]{νε}{φέ}[λαν]'
#       Child line 2: classes ['line', 'checked']
#       Found 9 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='ἀγ'
#           Span: classes=['syll', 'short'], content='κύ'
#           Span: classes=['syll', 'long'], content='λῳ'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='κρα'
#           Span: classes=['syll', 'long'], content='τί,'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='γλε'
#           Span: classes=['syll', 'short'], content='φά'
#           Span: classes=['syll', 'long'], content='ρων'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='ἁ'
#           Span: classes=['syll', 'short'], content='δὺ'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'long'], content='κλα'
#           Span: classes=['syll', 'long', 'link'], content='ΐ'
#           Span: classes=['syll', 'long'], content='στρον,'
#         Word 6: 4 sylls
#           Span: classes=['syll', 'short'], content='κα'
#           Span: classes=['syll', 'short'], content='τέ'
#           Span: classes=['syll', 'long'], content='χευ'
#           Span: classes=['syll', 'short'], content='ας·'
#         Word 7: 1 sylls
#           Span: classes=['syll', 'short'], content='ὁ'
#         Word 8: 1 sylls
#           Span: classes=['syll', 'long'], content='δὲ'
#         Word 9: 2 sylls
#           Span: classes=['syll', 'long'], content='κνώσ'
#           Span: classes=['syll', 'long', 'worddiv'], content='σων'
#       Final result: '[ἀγ]{κύ}[λῳ ][κρα][τί, ]{γλε}{φά}[ρων ][ἁ]{δὺ }[κλα][ΐ][στρον, ]{κα}{τέ}[χευ]{ας· }{ὁ }[δὲ ][κνώσ][σων]'
#       Extracted syllables: '[ἀγ]{κύ}[λῳ ][κρα][τί, ]{γλε}{φά}[ρων ][ἁ]{δὺ }[κλα][ΐ][στρον, ]{κα}{τέ}[χευ]{ας· }{ὁ }[δὲ ][κνώσ][σων]'
#       Child line 3: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='ὑ'
#           Span: classes=['syll', 'long'], content='γρὸν'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='νῶ'
#           Span: classes=['syll', 'short'], content='τον'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='αἰ'
#           Span: classes=['syll', 'long', 'link'], content='ω'
#           Span: classes=['syll', 'long'], content='ρεῖ,'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='τε'
#           Span: classes=['syll', 'long', 'worddiv'], content='αῖς'
#       Final result: '[ὑ][γρὸν ][νῶ]{τον }[αἰ][ω][ρεῖ, ]{τε}[αῖς]'
#       Extracted syllables: '[ὑ][γρὸν ][νῶ]{τον }[αἰ][ω][ρεῖ, ]{τε}[αῖς]'
#       Child line 4: classes ['line', 'checked', 'fifth']
#       Found 9 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long', 'link'], content='ῥι'
#           Span: classes=['syll', 'long'], content='παῖ'
#           Span: classes=['syll', 'short'], content='σι'
#         Word 2: 5 sylls
#           Span: classes=['syll', 'short'], content='κα'
#           Span: classes=['syll', 'long'], content='τα'
#           Span: classes=['syll', 'short'], content='σχό'
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long'], content='νος.'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long', 'link'], content='καὶ'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long'], content='γὰρ'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='βι'
#           Span: classes=['syll', 'long'], content='α'
#           Span: classes=['syll', 'long'], content='τὰς'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='Ἄ'
#           Span: classes=['syll', 'long'], content='ρης,'
#         Word 7: 3 sylls
#           Span: classes=['syll', 'long', 'link'], content='τρα'
#           Span: classes=['syll', 'long'], content='χεῖ'
#           Span: classes=['syll', 'short'], content='αν'
#         Word 8: 3 sylls
#           Span: classes=['syll', 'short'], content='ἄ'
#           Span: classes=['syll', 'long'], content='νευ'
#           Span: classes=['syll', 'short'], content='θε'
#         Word 9: 2 sylls
#           Span: classes=['syll', 'short'], content='λι'
#           Span: classes=['syll', 'long', 'worddiv'], content='πὼν'
#       Final result: '[ῥι][παῖ]{σι }{κα}[τα]{σχό}{με}[νος. ][καὶ ][γὰρ ]{βι}[α][τὰς ]{Ἄ}[ρης, ][τρα][χεῖ]{αν }{ἄ}[νευ]{θε }{λι}[πὼν]'
#       Extracted syllables: '[ῥι][παῖ]{σι }{κα}[τα]{σχό}{με}[νος. ][καὶ ][γὰρ ]{βι}[α][τὰς ]{Ἄ}[ρης, ][τρα][χεῖ]{αν }{ἄ}[νευ]{θε }{λι}[πὼν]'
#       Child line 5: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='ἐγ'
#           Span: classes=['syll', 'short'], content='χέ'
#           Span: classes=['syll', 'long'], content='ων'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='ἀκ'
#           Span: classes=['syll', 'long'], content='μάν,'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='ἰ'
#           Span: classes=['syll', 'long'], content='αί'
#           Span: classes=['syll', 'long', 'link'], content='νει'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='καρ'
#           Span: classes=['syll', 'short'], content='δί'
#           Span: classes=['syll', 'long', 'worddiv'], content='αν'
#       Final result: '[ἐγ]{χέ}[ων ][ἀκ][μάν, ]{ἰ}[αί][νει ][καρ]{δί}[αν]'
#       Extracted syllables: '[ἐγ]{χέ}[ων ][ἀκ][μάν, ]{ἰ}[αί][νει ][καρ]{δί}[αν]'
#       Child line 6: classes ['line', 'checked']
#       Found 14 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='κώ'
#           Span: classes=['syll', 'short'], content='μα'
#           Span: classes=['syll', 'short'], content='τι,'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='κῆ'
#           Span: classes=['syll', 'short'], content='λα'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='δὲ'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long'], content='καὶ'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'long'], content='δαι'
#           Span: classes=['syll', 'short'], content='μό'
#           Span: classes=['syll', 'long'], content='νων'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='θέλ'
#           Span: classes=['syll', 'long'], content='γει'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='φρέ'
#           Span: classes=['syll', 'short'], content='νας,'
#         Word 8: 2 sylls
#           Span: classes=['syll', 'long'], content='ἀμ'
#           Span: classes=['syll', 'short'], content='φί'
#         Word 9: 1 sylls
#           Span: classes=['syll', 'short'], content='τε'
#         Word 10: 3 sylls
#           Span: classes=['syll', 'long'], content='Λα'
#           Span: classes=['syll', 'long', 'unres', 'link'], content='τοί'
#           Span: classes=['syll', 'long'], content='δα'
#         Word 11: 3 sylls
#           Span: classes=['syll', 'short'], content='σο'
#           Span: classes=['syll', 'short'], content='φί'
#           Span: classes=['syll', 'long'], content='ᾳ'
#         Word 12: 4 sylls
#           Span: classes=['syll', 'short'], content='βα'
#           Span: classes=['syll', 'short'], content='θυ'
#           Span: classes=['syll', 'long'], content='κόλ'
#           Span: classes=['syll', 'long'], content='πων'
#         Word 13: 1 sylls
#           Span: classes=['syll', 'short'], content='τε'
#         Word 14: 2 sylls
#           Span: classes=['syll', 'long'], content='Μοι'
#           Span: classes=['syll', 'long', 'context-menu-active', 'link', 'worddiv'], content='σᾶν.'
#       Final result: '[κώ]{μα}{τι, }[κῆ]{λα }{δὲ }[καὶ ][δαι]{μό}[νων ][θέλ][γει ]{φρέ}{νας, }[ἀμ]{φί }{τε }[Λα][τοί][δα ]{σο}{φί}[ᾳ ]{βα}{θυ}[κόλ][πων ]{τε }[Μοι][σᾶν.]'
#       Extracted syllables: '[κώ]{μα}{τι, }[κῆ]{λα }{δὲ }[καὶ ][δαι]{μό}[νων ][θέλ][γει ]{φρέ}{νας, }[ἀμ]{φί }{τε }[Λα][τοί][δα ]{σο}{φί}[ᾳ ]{βα}{θυ}[κόλ][πων ]{τε }[Μοι][σᾶν.]'
#     Total lines collected: 6
#   Strophe 3: type='Epode', num='1'
#   Classes: ['Epode']
#     Processing as key: epode_1
#     Found 9 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#     Found 8 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='ὅσ'
#           Span: classes=['syll', 'short'], content='σα'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='δὲ'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long'], content='μὴ'
#         Word 4: 4 sylls
#           Span: classes=['syll', 'short'], content='πε'
#           Span: classes=['syll', 'short'], content='φί'
#           Span: classes=['syll', 'long'], content='λη'
#           Span: classes=['syll', 'long', 'link'], content='κε'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long'], content='Ζεύς,'
#         Word 6: 4 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='τύ'
#           Span: classes=['syll', 'long', 'link'], content='ζον'
#           Span: classes=['syll', 'long'], content='ται'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='βο'
#           Span: classes=['syll', 'long', 'worddiv'], content='ὰν'
#       Final result: '[ὅσ]{σα }{δὲ }[μὴ ]{πε}{φί}[λη][κε ][Ζεύς, ]{ἀ}[τύ][ζον][ται ]{βο}[ὰν]'
#       Extracted syllables: '[ὅσ]{σα }{δὲ }[μὴ ]{πε}{φί}[λη][κε ][Ζεύς, ]{ἀ}[τύ][ζον][ται ]{βο}[ὰν]'
#       Child line 2: classes ['line', 'checked']
#       Found 8 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'long'], content='Πι'
#           Span: classes=['syll', 'short'], content='ε'
#           Span: classes=['syll', 'short'], content='ρί'
#           Span: classes=['syll', 'long'], content='δων'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'short'], content='ΐ'
#           Span: classes=['syll', 'long'], content='ον'
#           Span: classes=['syll', 'short', 'exception', 'link'], content='τα,'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long'], content='γᾶν'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='τε'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long'], content='καὶ'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='πόν'
#           Span: classes=['syll', 'long'], content='τον'
#         Word 7: 1 sylls
#           Span: classes=['syll', 'short'], content='κατʼ'
#         Word 8: 5 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='μαι'
#           Span: classes=['syll', 'short'], content='μά'
#           Span: classes=['syll', 'short'], content='κε'
#           Span: classes=['syll', 'long', 'worddiv'], content='τον,'
#       Final result: '[Πι]{ε}{ρί}[δων ]{ἀ}{ΐ}[ον]{τα, }[γᾶν ]{τε }[καὶ ][πόν][τον ]{κατʼ }{ἀ}[μαι]{μά}{κε}[τον,]'
#       Extracted syllables: '[Πι]{ε}{ρί}[δων ]{ἀ}{ΐ}[ον]{τα, }[γᾶν ]{τε }[καὶ ][πόν][τον ]{κατʼ }{ἀ}[μαι]{μά}{κε}[τον,]'
#       Child line 3: classes ['line', 'checked', 'fifth']
#       Found 7 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='ὅς'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='τ᾽ἐν'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='αἰ'
#           Span: classes=['syll', 'long', 'link'], content='νᾷ'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='Ταρ'
#           Span: classes=['syll', 'short'], content='τά'
#           Span: classes=['syll', 'long'], content='ρῳ'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='κεῖ'
#           Span: classes=['syll', 'long'], content='ται,'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='θε'
#           Span: classes=['syll', 'long'], content='ῶν'
#         Word 7: 4 sylls
#           Span: classes=['syll', 'short'], content='πο'
#           Span: classes=['syll', 'short'], content='λέ'
#           Span: classes=['syll', 'short'], content='μι'
#           Span: classes=['syll', 'long', 'worddiv'], content='ος,'
#       Final result: '[ὅς ]{τ᾽ἐν }[αἰ][νᾷ ][Ταρ]{τά}[ρῳ ][κεῖ][ται, ]{θε}[ῶν ]{πο}{λέ}{μι}[ος,]'
#       Extracted syllables: '[ὅς ]{τ᾽ἐν }[αἰ][νᾷ ][Ταρ]{τά}[ρῳ ][κεῖ][ται, ]{θε}[ῶν ]{πο}{λέ}{μι}[ος,]'
#       Child line 4: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='Τυ'
#           Span: classes=['syll', 'long', 'worddiv'], content='φὼς'
#         Word 2: 7 sylls
#           Span: classes=['syll', 'short'], content='ἑ'
#           Span: classes=['syll', 'short'], content='κα'
#           Span: classes=['syll', 'long'], content='τον'
#           Span: classes=['syll', 'short'], content='τα'
#           Span: classes=['syll', 'short'], content='κά'
#           Span: classes=['syll', 'long'], content='ρα'
#           Span: classes=['syll', 'long', 'link'], content='νος·'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='τόν'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='πο'
#           Span: classes=['syll', 'long', 'worddiv'], content='τε'
#       Final result: '[Τυ][φὼς ]{ἑ}{κα}[τον]{τα}{κά}[ρα][νος· ][τόν ]{πο}[τε]'
#       Extracted syllables: '[Τυ][φὼς ]{ἑ}{κα}[τον]{τα}{κά}[ρα][νος· ][τόν ]{πο}[τε]'
#       Child line 5: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'short', 'resolved', 'res1', 'nodiv'], content='Κι'
#           Span: classes=['syll', 'short', 'resolved', 'res2'], content='λί'
#           Span: classes=['syll', 'short'], content='κι'
#           Span: classes=['syll', 'long'], content='ον'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='θρέ'
#           Span: classes=['syll', 'long'], content='ψεν'
#         Word 3: 5 sylls
#           Span: classes=['syll', 'short'], content='πο'
#           Span: classes=['syll', 'short'], content='λυ'
#           Span: classes=['syll', 'long'], content='ώ'
#           Span: classes=['syll', 'short'], content='νυ'
#           Span: classes=['syll', 'short'], content='μον'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='ἄν'
#           Span: classes=['syll', 'long', 'link'], content='τρον·'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long'], content='νῦν'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'short'], content='γε'
#         Word 7: 1 sylls
#           Span: classes=['syll', 'long', 'context-menu-active', 'worddiv'], content='μὰν'
#       Final result: '{€Κι}{€λί}{κι}[ον ][θρέ][ψεν ]{πο}{λυ}[ώ]{νυ}{μον }[ἄν][τρον· ][νῦν ]{γε }[μὰν]'
#       Extracted syllables: '{€Κι}{€λί}{κι}[ον ][θρέ][ψεν ]{πο}{λυ}[ώ]{νυ}{μον }[ἄν][τρον· ][νῦν ]{γε }[μὰν]'
#       Child line 6: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='ταί'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='θ᾽ὑ'
#           Span: classes=['syll', 'long'], content='πὲρ'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='Κύ'
#           Span: classes=['syll', 'long'], content='μας'
#         Word 4: 5 sylls
#           Span: classes=['syll', 'short'], content='ἁ'
#           Span: classes=['syll', 'short'], content='λι'
#           Span: classes=['syll', 'long'], content='ερ'
#           Span: classes=['syll', 'short'], content='κέ'
#           Span: classes=['syll', 'short'], content='ες'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long'], content='ὄχ'
#           Span: classes=['syll', 'long', 'link', 'worddiv'], content='θαι'
#       Final result: '[ταί ]{θ᾽ὑ}[πὲρ ][Κύ][μας ]{ἁ}{λι}[ερ]{κέ}{ες }[ὄχ][θαι]'
#       Extracted syllables: '[ταί ]{θ᾽ὑ}[πὲρ ][Κύ][μας ]{ἁ}{λι}[ερ]{κέ}{ες }[ὄχ][θαι]'
#       Child line 7: classes ['line', 'checked']
#       Found 8 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'short'], content='Σι'
#           Span: classes=['syll', 'short'], content='κε'
#           Span: classes=['syll', 'short'], content='λί'
#           Span: classes=['syll', 'long', 'worddiv'], content='α'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='τ᾽αὐ'
#           Span: classes=['syll', 'long'], content='τοῦ'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='πι'
#           Span: classes=['syll', 'long'], content='έ'
#           Span: classes=['syll', 'long', 'link', 'worddiv'], content='ζει'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='στέρ'
#           Span: classes=['syll', 'short'], content='να'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'long'], content='λαχ'
#           Span: classes=['syll', 'long', 'link'], content='νά'
#           Span: classes=['syll', 'long'], content='εν'
#           Span: classes=['syll', 'short'], content='τα·'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long'], content='κί'
#           Span: classes=['syll', 'long', 'link'], content='ων'
#         Word 7: 4 sylls
#           Span: classes=['syll', 'long'], content='δ᾽οὐ'
#           Span: classes=['syll', 'short'], content='ρα'
#           Span: classes=['syll', 'short'], content='νί'
#           Span: classes=['syll', 'long'], content='α'
#         Word 8: 3 sylls
#           Span: classes=['syll', 'short'], content='συ'
#           Span: classes=['syll', 'short'], content='νέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='χει,'
#       Final result: '{Σι}{κε}{λί}[α ][τ᾽αὐ][τοῦ ]{πι}[έ][ζει ][στέρ]{να }[λαχ][νά][εν]{τα· }[κί][ων ][δ᾽οὐ]{ρα}{νί}[α ]{συ}{νέ}[χει,]'
#       Extracted syllables: '{Σι}{κε}{λί}[α ][τ᾽αὐ][τοῦ ]{πι}[έ][ζει ][στέρ]{να }[λαχ][νά][εν]{τα· }[κί][ων ][δ᾽οὐ]{ρα}{νί}[α ]{συ}{νέ}[χει,]'
#       Child line 8: classes ['line', 'checked', 'fifth']
#       Found 6 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'short'], content='νι'
#           Span: classes=['syll', 'short'], content='φό'
#           Span: classes=['syll', 'long'], content='εσσʼ'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='Αἴτ'
#           Span: classes=['syll', 'long'], content='να,'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='πά'
#           Span: classes=['syll', 'short'], content='νε'
#           Span: classes=['syll', 'long', 'worddiv'], content='τες'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='χι'
#           Span: classes=['syll', 'short'], content='ό'
#           Span: classes=['syll', 'short'], content='νος'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'long'], content='ὀ'
#           Span: classes=['syll', 'long', 'link'], content='ξεί'
#           Span: classes=['syll', 'long'], content='ας'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'short'], content='τι'
#           Span: classes=['syll', 'long'], content='θή'
#           Span: classes=['syll', 'long', 'worddiv', 'link'], content='να·'
#       Final result: '{νι}{φό}[εσσʼ ][Αἴτ][να, ]{πά}{νε}[τες ]{χι}{ό}{νος }[ὀ][ξεί][ας ]{τι}[θή][να·]'
#       Extracted syllables: '{νι}{φό}[εσσʼ ][Αἴτ][να, ]{πά}{νε}[τες ]{χι}{ό}{νος }[ὀ][ξεί][ας ]{τι}[θή][να·]'
#     Total lines collected: 8
#   Strophe 4: type='Strophe', num='2'
#   Classes: ['strophe']
#     Processing as key: strophe_2
#     Found 7 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 6 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='τᾶς'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'long'], content='ρεύ'
#           Span: classes=['syll', 'long', 'link'], content='γον'
#           Span: classes=['syll', 'long'], content='ται'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='μὲν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='ἀ'
#           Span: classes=['syll', 'long', 'link'], content='πλά'
#           Span: classes=['syll', 'long'], content='του'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'short'], content='πυ'
#           Span: classes=['syll', 'short'], content='ρὸς'
#         Word 6: 4 sylls
#           Span: classes=['syll', 'long'], content='ἁ'
#           Span: classes=['syll', 'short'], content='γνό'
#           Span: classes=['syll', 'short'], content='τα'
#           Span: classes=['syll', 'long', 'worddiv'], content='ται'
#       Final result: '[τᾶς ]{ἐ}[ρεύ][γον][ται ]{μὲν }[ἀ][πλά][του ]{πυ}{ρὸς }[ἁ]{γνό}{τα}[ται]'
#       Extracted syllables: '[τᾶς ]{ἐ}[ρεύ][γον][ται ]{μὲν }[ἀ][πλά][του ]{πυ}{ρὸς }[ἁ]{γνό}{τα}[ται]'
#       Child line 2: classes ['line', 'checked']
#       Found 9 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='ἐκ'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='μυ'
#           Span: classes=['syll', 'long'], content='χῶν'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='πα'
#           Span: classes=['syll', 'long'], content='γαί·'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='πο'
#           Span: classes=['syll', 'short'], content='τα'
#           Span: classes=['syll', 'long'], content='μοὶ'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'long'], content='δ᾽ἁ'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long'], content='ραι'
#           Span: classes=['syll', 'long', 'link'], content='σιν'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'long'], content='μὲν'
#         Word 7: 4 sylls
#           Span: classes=['syll', 'short'], content='προ'
#           Span: classes=['syll', 'short'], content='χέ'
#           Span: classes=['syll', 'long'], content='ον'
#           Span: classes=['syll', 'short'], content='τι'
#         Word 8: 2 sylls
#           Span: classes=['syll', 'short'], content='ῥό'
#           Span: classes=['syll', 'long'], content='ον'
#         Word 9: 2 sylls
#           Span: classes=['syll', 'long'], content='κα'
#           Span: classes=['syll', 'long', 'worddiv'], content='πνοῦ'
#       Final result: '[ἐκ ]{μυ}[χῶν ][πα][γαί· ]{πο}{τα}[μοὶ ][δ᾽ἁ]{μέ}[ραι][σιν ][μὲν ]{προ}{χέ}[ον]{τι }{ῥό}[ον ][κα][πνοῦ]'
#       Extracted syllables: '[ἐκ ]{μυ}[χῶν ][πα][γαί· ]{πο}{τα}[μοὶ ][δ᾽ἁ]{μέ}[ραι][σιν ][μὲν ]{προ}{χέ}[ον]{τι }{ῥό}[ον ][κα][πνοῦ]'
#       Child line 3: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='αἴ'
#           Span: classes=['syll', 'long'], content='θωνʼ·'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long'], content='ἀλλʼ'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='ἐν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='ὄρφ'
#           Span: classes=['syll', 'long', 'link'], content='ναι'
#           Span: classes=['syll', 'long'], content='σιν'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'short'], content='πέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='τρας'
#       Final result: '[αἴ][θωνʼ· ][ἀλλʼ ]{ἐν }[ὄρφ][ναι][σιν ]{πέ}[τρας]'
#       Extracted syllables: '[αἴ][θωνʼ· ][ἀλλʼ ]{ἐν }[ὄρφ][ναι][σιν ]{πέ}[τρας]'
#       Child line 4: classes ['line', 'checked']
#       Found 10 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long', 'link'], content='φοί'
#           Span: classes=['syll', 'long'], content='νισ'
#           Span: classes=['syll', 'short'], content='σα'
#         Word 2: 5 sylls
#           Span: classes=['syll', 'short'], content='κυ'
#           Span: classes=['syll', 'long'], content='λιν'
#           Span: classes=['syll', 'short'], content='δο'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long'], content='να'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long', 'link'], content='φλὸξ'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long'], content='ἐς'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='βα'
#           Span: classes=['syll', 'long'], content='θεῖ'
#           Span: classes=['syll', 'long'], content='αν'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='φέ'
#           Span: classes=['syll', 'long'], content='ρει'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='πόν'
#           Span: classes=['syll', 'long'], content='του'
#         Word 8: 2 sylls
#           Span: classes=['syll', 'short'], content='πλά'
#           Span: classes=['syll', 'short'], content='κα'
#         Word 9: 1 sylls
#           Span: classes=['syll', 'long'], content='σὺν'
#         Word 10: 3 sylls
#           Span: classes=['syll', 'short'], content='πα'
#           Span: classes=['syll', 'short'], content='τά'
#           Span: classes=['syll', 'long', 'worddiv'], content='γῳ.'
#       Final result: '[φοί][νισ]{σα }{κυ}[λιν]{δο}{μέ}[να ][φλὸξ ][ἐς ]{βα}[θεῖ][αν ]{φέ}[ρει ][πόν][του ]{πλά}{κα }[σὺν ]{πα}{τά}[γῳ.]'
#       Extracted syllables: '[φοί][νισ]{σα }{κυ}[λιν]{δο}{μέ}[να ][φλὸξ ][ἐς ]{βα}[θεῖ][αν ]{φέ}[ρει ][πόν][του ]{πλά}{κα }[σὺν ]{πα}{τά}[γῳ.]'
#       Child line 5: classes ['line', 'checked', 'fifth']
#       Found 4 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='κεῖ'
#           Span: classes=['syll', 'short'], content='νο'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'long'], content='δ᾽Ἁ'
#           Span: classes=['syll', 'long', 'link'], content='φαί'
#           Span: classes=['syll', 'long'], content='στοι'
#           Span: classes=['syll', 'short'], content='ο'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='κρου'
#           Span: classes=['syll', 'long', 'link'], content='νοὺς'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='ἑρ'
#           Span: classes=['syll', 'short'], content='πε'
#           Span: classes=['syll', 'long', 'worddiv'], content='τὸν'
#       Final result: '[κεῖ]{νο }[δ᾽Ἁ][φαί][στοι]{ο }[κρου][νοὺς ][ἑρ]{πε}[τὸν]'
#       Extracted syllables: '[κεῖ]{νο }[δ᾽Ἁ][φαί][στοι]{ο }[κρου][νοὺς ][ἑρ]{πε}[τὸν]'
#       Child line 6: classes ['line', 'checked']
#       Found 11 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'long'], content='δει'
#           Span: classes=['syll', 'short'], content='νο'
#           Span: classes=['syll', 'short'], content='τά'
#           Span: classes=['syll', 'long'], content='τους'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'short'], content='να'
#           Span: classes=['syll', 'long'], content='πέμ'
#           Span: classes=['syll', 'long'], content='πει·'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='τέ'
#           Span: classes=['syll', 'long'], content='ρας'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long', 'link'], content='μὲν'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'long'], content='θαυ'
#           Span: classes=['syll', 'short'], content='μά'
#           Span: classes=['syll', 'short'], content='σι'
#           Span: classes=['syll', 'long'], content='ον'
#         Word 6: 4 sylls
#           Span: classes=['syll', 'short'], content='προ'
#           Span: classes=['syll', 'short'], content='σι'
#           Span: classes=['syll', 'long'], content='δέ'
#           Span: classes=['syll', 'long', 'unres', 'link'], content='σθαι,'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long'], content='θαῦ'
#           Span: classes=['syll', 'short'], content='μα'
#         Word 8: 1 sylls
#           Span: classes=['syll', 'short'], content='δὲ'
#         Word 9: 1 sylls
#           Span: classes=['syll', 'long'], content='καὶ'
#         Word 10: 4 sylls
#           Span: classes=['syll', 'short'], content='πα'
#           Span: classes=['syll', 'short'], content='ρε'
#           Span: classes=['syll', 'long'], content='όν'
#           Span: classes=['syll', 'long'], content='των'
#         Word 11: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='κοῦ'
#           Span: classes=['syll', 'long', 'link', 'worddiv'], content='σαι,'
#       Final result: '[δει]{νο}{τά}[τους ]{ἀ}{να}[πέμ][πει· ]{τέ}[ρας ][μὲν ][θαυ]{μά}{σι}[ον ]{προ}{σι}[δέ][σθαι, ][θαῦ]{μα }{δὲ }[καὶ ]{πα}{ρε}[όν][των ]{ἀ}[κοῦ][σαι,]'
#       Extracted syllables: '[δει]{νο}{τά}[τους ]{ἀ}{να}[πέμ][πει· ]{τέ}[ρας ][μὲν ][θαυ]{μά}{σι}[ον ]{προ}{σι}[δέ][σθαι, ][θαῦ]{μα }{δὲ }[καὶ ]{πα}{ρε}[όν][των ]{ἀ}[κοῦ][σαι,]'
#     Total lines collected: 6
#   Strophe 5: type='Antistrophe', num='2'
#   Classes: ['strophe', 'antistrophe']
#     Processing as key: antistrophe_2
#     Found 7 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 6 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='οἷ'
#           Span: classes=['syll', 'short'], content='ον'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='Αἴτ'
#           Span: classes=['syll', 'long', 'link'], content='νας'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long'], content='ἐν'
#         Word 4: 4 sylls
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long'], content='λαμ'
#           Span: classes=['syll', 'long', 'link'], content='φύλ'
#           Span: classes=['syll', 'long'], content='λοις'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='δέ'
#           Span: classes=['syll', 'short'], content='δε'
#           Span: classes=['syll', 'long'], content='ται'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'short'], content='κο'
#           Span: classes=['syll', 'short'], content='ρυ'
#           Span: classes=['syll', 'long', 'worddiv'], content='φαῖς'
#       Final result: '[οἷ]{ον }[Αἴτ][νας ][ἐν ]{με}[λαμ][φύλ][λοις ]{δέ}{δε}[ται ]{κο}{ρυ}[φαῖς]'
#       Extracted syllables: '[οἷ]{ον }[Αἴτ][νας ][ἐν ]{με}[λαμ][φύλ][λοις ]{δέ}{δε}[ται ]{κο}{ρυ}[φαῖς]'
#       Child line 2: classes ['line', 'checked']
#       Found 9 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='καὶ'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='πέ'
#           Span: classes=['syll', 'long'], content='δῳ,'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='στρω'
#           Span: classes=['syll', 'long'], content='μνὰ'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='δὲ'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='χα'
#           Span: classes=['syll', 'long'], content='ράσ'
#           Span: classes=['syll', 'long'], content='σοισʼ'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='ἅ'
#           Span: classes=['syll', 'long'], content='παν'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='νῶ'
#           Span: classes=['syll', 'long'], content='τον'
#         Word 8: 6 sylls
#           Span: classes=['syll', 'short'], content='πο'
#           Span: classes=['syll', 'short'], content='τι'
#           Span: classes=['syll', 'long'], content='κε'
#           Span: classes=['syll', 'short'], content='κλι'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long'], content='νον'
#         Word 9: 2 sylls
#           Span: classes=['syll', 'long'], content='κεν'
#           Span: classes=['syll', 'long', 'worddiv'], content='τεῖ.'
#       Final result: '[καὶ ]{πέ}[δῳ, ][στρω][μνὰ ]{δὲ }{χα}[ράσ][σοισʼ ]{ἅ}[παν ][νῶ][τον ]{πο}{τι}[κε]{κλι}{μέ}[νον ][κεν][τεῖ.]'
#       Extracted syllables: '[καὶ ]{πέ}[δῳ, ][στρω][μνὰ ]{δὲ }{χα}[ράσ][σοισʼ ]{ἅ}[παν ][νῶ][τον ]{πο}{τι}[κε]{κλι}{μέ}[νον ][κεν][τεῖ.]'
#       Child line 3: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='εἴ'
#           Span: classes=['syll', 'long'], content='η,'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long'], content='Ζεῦ,'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='τὶν'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='εἴ'
#           Span: classes=['syll', 'long', 'link'], content='η'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'long'], content='ἁν'
#           Span: classes=['syll', 'short'], content='δά'
#           Span: classes=['syll', 'long', 'worddiv'], content='νειν,'
#       Final result: '[εἴ][η, ][Ζεῦ, ]{τὶν }[εἴ][η ][ἁν]{δά}[νειν,]'
#       Extracted syllables: '[εἴ][η, ][Ζεῦ, ]{τὶν }[εἴ][η ][ἁν]{δά}[νειν,]'
#       Child line 4: classes ['line', 'checked', 'fifth']
#       Found 10 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long', 'link'], content='ὃς'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long'], content='τοῦτʼ'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'short'], content='φέ'
#           Span: classes=['syll', 'long'], content='πεις'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='ὄ'
#           Span: classes=['syll', 'short'], content='ρος,'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'long'], content='εὐ'
#           Span: classes=['syll', 'long', 'link'], content='κάρ'
#           Span: classes=['syll', 'long'], content='ποι'
#           Span: classes=['syll', 'short'], content='ο'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long'], content='γαί'
#           Span: classes=['syll', 'long'], content='ας'
#         Word 7: 3 sylls
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long'], content='τω'
#           Span: classes=['syll', 'long', 'link'], content='πον,'
#         Word 8: 1 sylls
#           Span: classes=['syll', 'long'], content='τοῦ'
#         Word 9: 1 sylls
#           Span: classes=['syll', 'short'], content='μὲν'
#         Word 10: 5 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
# ...
#       Found 6 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long', 'link'], content='χριμ'
#           Span: classes=['syll', 'long'], content='φθέν'
#           Span: classes=['syll', 'short'], content='τα'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='σὺν'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='ἔν'
#           Span: classes=['syll', 'short'], content='τε'
#           Span: classes=['syll', 'short'], content='σι'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='μι'
#           Span: classes=['syll', 'long', 'link'], content='μή'
#           Span: classes=['syll', 'long'], content='σαιτʼ'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'long'], content='ρι'
#           Span: classes=['syll', 'long', 'link'], content='κλάγ'
#           Span: classes=['syll', 'long'], content='κταν'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='γό'
#           Span: classes=['syll', 'long', 'worddiv'], content='ον.'
#       Final result: '[χριμ][φθέν]{τα }{σὺν }[ἔν]{τε}{σι }[μι][μή][σαιτʼ ]{ἐ}[ρι][κλάγ][κταν ]{γό}[ον.]'
#       Extracted syllables: '[χριμ][φθέν]{τα }{σὺν }[ἔν]{τε}{σι }[μι][μή][σαιτʼ ]{ἐ}[ρι][κλάγ][κταν ]{γό}[ον.]'
#       Child line 6: classes ['line', 'checked']
#       Found 8 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='εὗ'
#           Span: classes=['syll', 'long'], content='ρεν'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='θε'
#           Span: classes=['syll', 'short'], content='ός·'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='ἀλ'
#           Span: classes=['syll', 'short'], content='λά'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='νιν'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long'], content='εὑ'
#           Span: classes=['syll', 'long', 'link'], content='ροῖσʼ'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'long'], content='ἀν'
#           Span: classes=['syll', 'short'], content='δρά'
#           Span: classes=['syll', 'long'], content='σι'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='θνα'
#           Span: classes=['syll', 'long'], content='τοῖς'
#         Word 8: 2 sylls
#           Span: classes=['syll', 'short'], content='ἔ'
#           Span: classes=['syll', 'long', 'worddiv'], content='χειν,'
#       Final result: '[εὗ][ρεν ]{θε}{ός· }[ἀλ]{λά }{νιν }[εὑ][ροῖσʼ ][ἀν]{δρά}[σι ][θνα][τοῖς ]{ἔ}[χειν,]'
#       Extracted syllables: '[εὗ][ρεν ]{θε}{ός· }[ἀλ]{λά }{νιν }[εὑ][ροῖσʼ ][ἀν]{δρά}[σι ][θνα][τοῖς ]{ἔ}[χειν,]'
#       Child line 7: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'long'], content='ὠ'
#           Span: classes=['syll', 'short'], content='νό'
#           Span: classes=['syll', 'short'], content='μα'
#           Span: classes=['syll', 'long'], content='σεν'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='κε'
#           Span: classes=['syll', 'short'], content='φα'
#           Span: classes=['syll', 'long'], content='λᾶν'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='πολ'
#           Span: classes=['syll', 'long'], content='λᾶν'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='νό'
#           Span: classes=['syll', 'long', 'worddiv'], content='μον,'
#       Final result: '[ὠ]{νό}{μα}[σεν ]{κε}{φα}[λᾶν ][πολ][λᾶν ]{νό}[μον,]'
#       Extracted syllables: '[ὠ]{νό}{μα}[σεν ]{κε}{φα}[λᾶν ][πολ][λᾶν ]{νό}[μον,]'
#       Child line 8: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='εὐ'
#           Span: classes=['syll', 'short'], content='κλε'
#           Span: classes=['syll', 'long'], content='ᾶ'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'long', 'link'], content='λα'
#           Span: classes=['syll', 'long'], content='οσ'
#           Span: classes=['syll', 'short'], content='σό'
#           Span: classes=['syll', 'long'], content='ων'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='μνα'
#           Span: classes=['syll', 'long', 'worddiv'], content='στῆρʼ'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='γώ'
#           Span: classes=['syll', 'long', 'link', 'worddiv'], content='νων,'
#       Final result: '[εὐ]{κλε}[ᾶ ][λα][οσ]{σό}[ων ][μνα][στῆρʼ ]{ἀ}[γώ][νων,]'
#       Extracted syllables: '[εὐ]{κλε}[ᾶ ][λα][οσ]{σό}[ων ][μνα][στῆρʼ ]{ἀ}[γώ][νων,]'
#     Total lines collected: 8
#   Strophe 4: type='Strophe', num='4'
#   Classes: ['strophe']
#     Processing as key: strophe_4
#     Found 9 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 8 child line divs
#       Child line 1: classes ['line', 'checked', 'fifth']
#       Found 6 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='λε'
#           Span: classes=['syll', 'long'], content='πτοῦ'
#         Word 2: 6 sylls
#           Span: classes=['syll', 'short'], content='δι'
#           Span: classes=['syll', 'short'], content='α'
#           Span: classes=['syll', 'long'], content='νισ'
#           Span: classes=['syll', 'short'], content='σό'
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long'], content='νον'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='χαλ'
#           Span: classes=['syll', 'long', 'worddiv'], content='κοῦ'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='θα'
#           Span: classes=['syll', 'short'], content='μὰ'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long'], content='καὶ'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'short'], content='δο'
#           Span: classes=['syll', 'short'], content='νά'
#           Span: classes=['syll', 'long', 'worddiv'], content='κων,'
#       Final result: '[λε][πτοῦ ]{δι}{α}[νισ]{σό}{με}[νον ][χαλ][κοῦ ]{θα}{μὰ }[καὶ ]{δο}{νά}[κων,]'
#       Extracted syllables: '[λε][πτοῦ ]{δι}{α}[νισ]{σό}{με}[νον ][χαλ][κοῦ ]{θα}{μὰ }[καὶ ]{δο}{νά}[κων,]'
#       Child line 2: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='τοὶ'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='πα'
#           Span: classes=['syll', 'short'], content='ρὰ'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'long'], content='καλ'
#           Span: classes=['syll', 'short'], content='λι'
#           Span: classes=['syll', 'short'], content='χό'
#           Span: classes=['syll', 'long', 'worddiv'], content='ρῳ'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long', 'link'], content='ναί'
#           Span: classes=['syll', 'long'], content='οι'
#           Span: classes=['syll', 'short'], content='σι'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'short'], content='πό'
#           Span: classes=['syll', 'long'], content='λει'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'short'], content='Χα'
#           Span: classes=['syll', 'short'], content='ρί'
#           Span: classes=['syll', 'long', 'worddiv'], content='των.'
#       Final result: '[τοὶ ]{πα}{ρὰ }[καλ]{λι}{χό}[ρῳ ][ναί][οι]{σι }{πό}[λει ]{Χα}{ρί}[των.]'
#       Extracted syllables: '[τοὶ ]{πα}{ρὰ }[καλ]{λι}{χό}[ρῳ ][ναί][οι]{σι }{πό}[λει ]{Χα}{ρί}[των.]'
#       Child line 3: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'long', 'link'], content='Κα'
#           Span: classes=['syll', 'long'], content='φι'
#           Span: classes=['syll', 'short'], content='σί'
#           Span: classes=['syll', 'short'], content='δος'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long'], content='ἐν'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='τε'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long'], content='νει,'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='πι'
#           Span: classes=['syll', 'long'], content='στοὶ'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='χο'
#           Span: classes=['syll', 'long'], content='ρευ'
#           Span: classes=['syll', 'long', 'link'], content='τᾶν'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'long'], content='μάρ'
#           Span: classes=['syll', 'short'], content='τυ'
#           Span: classes=['syll', 'long', 'worddiv'], content='ρες.'
#       Final result: '[Κα][φι]{σί}{δος }[ἐν ]{τε}{μέ}[νει, ][πι][στοὶ ]{χο}[ρευ][τᾶν ][μάρ]{τυ}[ρες.]'
#       Extracted syllables: '[Κα][φι]{σί}{δος }[ἐν ]{τε}{μέ}[νει, ][πι][στοὶ ]{χο}[ρευ][τᾶν ][μάρ]{τυ}[ρες.]'
#       Child line 4: classes ['line', 'checked']
#       Found 8 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='εἰ'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='δέ'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='τις'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='ὄλ'
#           Span: classes=['syll', 'short'], content='βος'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'short'], content='ἐν'
#         Word 6: 4 sylls
#           Span: classes=['syll', 'long'], content='ἀν'
#           Span: classes=['syll', 'long', 'link'], content='θρώ'
#           Span: classes=['syll', 'long'], content='ποι'
#           Span: classes=['syll', 'short'], content='σιν,'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='ἄ'
#           Span: classes=['syll', 'long'], content='νευ'
#         Word 8: 3 sylls
#           Span: classes=['syll', 'short'], content='κα'
#           Span: classes=['syll', 'short'], content='μά'
#           Span: classes=['syll', 'long', 'worddiv'], content='του'
#       Final result: '[εἰ ]{δέ }{τις }[ὄλ]{βος }{ἐν }[ἀν][θρώ][ποι]{σιν, }{ἄ}[νευ ]{κα}{μά}[του]'
#       Extracted syllables: '[εἰ ]{δέ }{τις }[ὄλ]{βος }{ἐν }[ἀν][θρώ][ποι]{σιν, }{ἄ}[νευ ]{κα}{μά}[του]'
#       Child line 5: classes ['line', 'checked']
#       Found 8 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long', 'link'], content='οὐ'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='φαί'
#           Span: classes=['syll', 'short'], content='νε'
#           Span: classes=['syll', 'short'], content='ται·'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long'], content='ἐκ'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='δὲ'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'short'], content='τε'
#           Span: classes=['syll', 'long'], content='λευ'
#           Span: classes=['syll', 'long', 'link'], content='τά'
#           Span: classes=['syll', 'long'], content='σει'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'short'], content='νιν'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long'], content='ἤ'
#           Span: classes=['syll', 'long', 'link'], content='τοι'
#         Word 8: 3 sylls
#           Span: classes=['syll', 'long'], content='σά'
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long', 'worddiv'], content='ρον'
#       Final result: '[οὐ ][φαί]{νε}{ται· }[ἐκ ]{δὲ }{τε}[λευ][τά][σει ]{νιν }[ἤ][τοι ][σά]{με}[ρον]'
#       Extracted syllables: '[οὐ ][φαί]{νε}{ται· }[ἐκ ]{δὲ }{τε}[λευ][τά][σει ]{νιν }[ἤ][τοι ][σά]{με}[ρον]'
#       Child line 6: classes ['line', 'checked', 'fifth']
#       Found 7 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long', 'link'], content='δαί'
#           Span: classes=['syll', 'long'], content='μων—'
#           Span: classes=['syll', 'short'], content='τὸ'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='δὲ'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='μόρ'
#           Span: classes=['syll', 'short'], content='σι'
#           Span: classes=['syll', 'short'], content='μον'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long'], content='οὐ'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'long', 'link'], content='παρ'
#           Span: classes=['syll', 'long'], content='φυ'
#           Span: classes=['syll', 'short'], content='κτόν,'
#           Span: classes=['syll', 'long'], content='—ἀλλʼ'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='ἔ'
#           Span: classes=['syll', 'long'], content='σται'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='χρό'
#           Span: classes=['syll', 'long', 'worddiv'], content='νος'
#       Final result: '[δαί][μων—]{τὸ }{δὲ }[μόρ]{σι}{μον }[οὐ ][παρ][φυ]{κτόν,}[—ἀλλʼ ][ἔ][σται ]{χρό}[νος]'
#       Extracted syllables: '[δαί][μων—]{τὸ }{δὲ }[μόρ]{σι}{μον }[οὐ ][παρ][φυ]{κτόν,}[—ἀλλʼ ][ἔ][σται ]{χρό}[νος]'
#       Child line 7: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='οὗ'
#           Span: classes=['syll', 'short'], content='τος,'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='ὃ'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long'], content='καί'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='τινʼ'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='ελ'
#           Span: classes=['syll', 'short', 'exception', 'link'], content='πτί'
#           Span: classes=['syll', 'long'], content='ᾳ'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='βα'
#           Span: classes=['syll', 'long', 'worddiv'], content='λὼν'
#       Final result: '[οὗ]{τος, }{ὃ }[καί ]{τινʼ }{ἀ}[ελ]{πτί}[ᾳ ]{βα}[λὼν]'
#       Extracted syllables: '[οὗ]{τος, }{ὃ }[καί ]{τινʼ }{ἀ}[ελ]{πτί}[ᾳ ]{βα}[λὼν]'
#       Child line 8: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='ἔμ'
#           Span: classes=['syll', 'short'], content='πα'
#           Span: classes=['syll', 'long'], content='λιν'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='γνώ'
#           Span: classes=['syll', 'long'], content='μας'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='τὸ'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long'], content='μὲν'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long', 'link'], content='δώ'
#           Span: classes=['syll', 'long', 'worddiv'], content='σει,'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'short'], content='τὸ'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long'], content='δ᾽οὔ'
#           Span: classes=['syll', 'long', 'link', 'worddiv'], content='πω.'
#       Final result: '[ἔμ]{πα}[λιν ][γνώ][μας ]{τὸ }[μὲν ][δώ][σει, ]{τὸ }[δ᾽οὔ][πω.]'
#       Extracted syllables: '[ἔμ]{πα}[λιν ][γνώ][μας ]{τὸ }[μὲν ][δώ][σει, ]{τὸ }[δ᾽οὔ][πω.]'
#     Total lines collected: 8

# %% [markdown]
# ## 3. Compilation

# %% [markdown]
# See compiler.py
