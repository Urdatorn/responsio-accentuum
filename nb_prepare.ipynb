# %% [markdown]
# # Prepare verse corpus for the responsion analysis

# %% [markdown]
# ## 1. Extraction

# %%
from src.extract import transform_tei

input_file = "data/source/01_olympia.xml"
output_file = "data/raw/01_olympia.xml"

transform_tei(input_file, output_file)
# Out:
# [WARNING] Canticum 2 has inconsistent strophe lengths: [20, 21, 20, 20, 20]
# [WARNING] Canticum 3 has inconsistent strophe lengths: [30, 15]
# [WARNING] Canticum 9 has inconsistent strophe lengths: [27, 28, 28, 28]

# %% [markdown]
# ## 2. Macronization

# %%
from src.macronize import macronize_xml
#from src.tidy import tidy_xml

input_file = "data/raw/ol01.xml"
output_file = "data/macronized/ol01_macronized.xml"

macronize_xml(input_file, output_file)
# Out:
# 100%|██████████| 120/120 [00:04<00:00, 25.80it/s]

# %% [markdown]
# ## 2a. Rule scansion

# %%
from src.scan import rule_scansion

input = "ἁνίκ' ἄγκυ_ρα^ν ποτὶ^ χαλκόγενυ^ν"
scanned = rule_scansion(input)
print(scanned)
input = "νυκτὶ^ κοινά_σαντες ὁδόν, Κρονί^δᾳ δὲ τˈρά^φεν Χίρωνι^ δῶκα^ν."
scanned = rule_scansion(input)
print(f"\n{scanned}")
input = "'Οὔ τί^ που οὗτος Ἀπόλλων, οὐδὲ μὰ_ν χαλκάρμα^τός ἐστι^ πόσι^ς"
scanned = rule_scansion(input)
print(f"\n{scanned}")
input = "εἰ μετάλλατόν τι^· καὶ ὡς τά^χος ὀτˈρύνει με τεύχειν να_ῒ^ πομπάν."
scanned = rule_scansion(input)
print(f"\n{scanned}")
# Out:
# {ἁ}{νί}[κ' ἄγ][κυ_][ρα^ν ]{πο}{τὶ^ }[χαλ]{κό}{γε}[νυ^ν]
#
# [νυκ]{τὶ^ }[κοι][νά_][σαν]{τε}{ς ὁ}[δόν, ]{Κρο}{νί^}[δᾳ ][δὲ τˈ]{ρά^}[φεν ]{Χί}[ρω]{νι^ }[δῶ][κα^ν.]
#
# ['Οὔ ]{τί^ }{που }[οὗ]{το}[ς Ἀ][πόλ][λω][ν, οὐ]{δὲ }[μὰ_ν ][χαλ][κάρ]{μα^}{τό}[ς ἐσ]{τι^ }{πό}[σι^ς]
#
# [εἰ ]{με}[τάλ]{λα}[τόν ]{τι^· }{καὶ }[ὡς ]{τά^}{χο}[ς ὀτˈ]{ρύ}[νει ]{με }[τεύ][χειν ][να_]{ῒ^ }[πομ][πάν.]

# %%
from src.scan import scan_xml

input_file = "data/raw/ol01.xml"
output_file = "data/scan/ol01.xml"
scan_xml(input_file, output_file, debug=False)
# Out:
# 120it [00:00, 671.42it/s]

# %% [markdown]
# ## 2b. Extract scansion from Hypotactic

# %%
from scan_ht import extract_strophic_syllables_from_html, create_tei_xml

html_file = "ht/olympians.html"

poems_dict = extract_strophic_syllables_from_html(html_file, debug=True)

tei_xml = create_tei_xml(poems_dict, title="Olympian Odes", author="Pindar", output_file="data/scan/ht_olympians.xml", debug=False)
# Out:
# Processing file: ht/olympians.html
# Found 14 poem divs
#
# Processing poem 1
# Found 12 strophe divs in poem 1
#   Strophe 1: type='Strophe', num='1'
#   Classes: ['strophe']
#     Processing as key: strophe_1
#     Found 12 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 11 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 8 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'short'], content='ἄ'
#           Span: classes=['syll', 'long'], content='ρι'
#           Span: classes=['syll', 'long'], content='στον'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='μὲν'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='ὕ'
#           Span: classes=['syll', 'long'], content='δωρ,'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='ὁ'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long'], content='δὲ'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long'], content='χρυ'
#           Span: classes=['syll', 'short'], content='σὸς'
#         Word 7: 4 sylls
#           Span: classes=['syll', 'long'], content='αἰ'
#           Span: classes=['syll', 'short'], content='θό'
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long'], content='νον'
#         Word 8: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='πῦρ'
#       Final result: '{ἄ}[ρι][στον ]{μὲν }{ὕ}[δωρ, ]{ὁ }[δὲ ][χρυ]{σὸς }[αἰ]{θό}{με}[νον ][πῦρ]'
#       Extracted syllables: '{ἄ}[ρι][στον ]{μὲν }{ὕ}[δωρ, ]{ὁ }[δὲ ][χρυ]{σὸς }[αἰ]{θό}{με}[νον ][πῦρ]'
#       Child line 2: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='ἅ'
#           Span: classes=['syll', 'short'], content='τε'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='δι'
#           Span: classes=['syll', 'long'], content='α'
#           Span: classes=['syll', 'short'], content='πρέ'
#           Span: classes=['syll', 'long'], content='πει'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='νυ'
#           Span: classes=['syll', 'short'], content='κτὶ'
#         Word 4: 4 sylls
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long'], content='γά'
#           Span: classes=['syll', 'short'], content='νο'
#           Span: classes=['syll', 'short'], content='ρος'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'long'], content='ἔ'
#           Span: classes=['syll', 'short'], content='ξο'
#           Span: classes=['syll', 'short'], content='χα'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long'], content='πλού'
#           Span: classes=['syll', 'long', 'worddiv'], content='του·'
#       Final result: '{ἅ}{τε }{δι}[α]{πρέ}[πει ][νυ]{κτὶ }{με}[γά]{νο}{ρος }[ἔ]{ξο}{χα }[πλού][του·]'
#       Extracted syllables: '{ἅ}{τε }{δι}[α]{πρέ}[πει ][νυ]{κτὶ }{με}[γά]{νο}{ρος }[ἔ]{ξο}{χα }[πλού][του·]'
#       Child line 3: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='εἰ'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='δ᾽ἄ'
#           Span: classes=['syll', 'long'], content='ε'
#           Span: classes=['syll', 'short'], content='θλα'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='γα'
#           Span: classes=['syll', 'short'], content='ρύ'
#           Span: classes=['syll', 'long', 'worddiv'], content='εν'
#       Final result: '[εἰ ]{δ᾽ἄ}[ε]{θλα }[γα]{ρύ}[εν]'
#       Extracted syllables: '[εἰ ]{δ᾽ἄ}[ε]{θλα }[γα]{ρύ}[εν]'
#       Child line 4: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='ἔλ'
#           Span: classes=['syll', 'short'], content='δε'
#           Span: classes=['syll', 'long'], content='αι,'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='φί'
#           Span: classes=['syll', 'short'], content='λον'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='ἦ'
#           Span: classes=['syll', 'long', 'worddiv'], content='τορ,'
#       Final result: '[ἔλ]{δε}[αι, ]{φί}{λον }[ἦ][τορ,]'
#       Extracted syllables: '[ἔλ]{δε}[αι, ]{φί}{λον }[ἦ][τορ,]'
#       Child line 5: classes ['line', 'checked', 'fifth']
#       Found 3 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='μη'
#           Span: classes=['syll', 'short'], content='κέτʼ'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='ἀε'
#           Span: classes=['syll', 'short'], content='λί'
#           Span: classes=['syll', 'long'], content='ου'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='σκό'
#           Span: classes=['syll', 'long', 'worddiv'], content='πει'
#       Final result: '[μη]{κέτʼ }[ἀε]{λί}[ου ]{σκό}[πει]'
#       Extracted syllables: '[μη]{κέτʼ }[ἀε]{λί}[ου ]{σκό}[πει]'
#       Child line 6: classes ['line', 'checked']
#       Found 9 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='ἄλ'
#           Span: classes=['syll', 'short'], content='λο'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'long'], content='θαλ'
#           Span: classes=['syll', 'short'], content='πνό'
#           Span: classes=['syll', 'short'], content='τε'
#           Span: classes=['syll', 'short'], content='ρον'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='ἐν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='ἁ'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long'], content='ρᾳ'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='φα'
#           Span: classes=['syll', 'long'], content='εν'
#           Span: classes=['syll', 'short'], content='νὸν'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long'], content='ἄ'
#           Span: classes=['syll', 'short'], content='στρον'
#         Word 7: 3 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'long'], content='ρή'
#           Span: classes=['syll', 'long'], content='μας'
#         Word 8: 1 sylls
#           Span: classes=['syll', 'short'], content='διʼ'
#         Word 9: 3 sylls
#           Span: classes=['syll', 'long'], content='αἰ'
#           Span: classes=['syll', 'short'], content='θέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='ρος,'
#       Final result: '[ἄλ]{λο }[θαλ]{πνό}{τε}{ρον }{ἐν }[ἁ]{μέ}[ρᾳ ]{φα}[εν]{νὸν }[ἄ]{στρον }{ἐ}[ρή][μας ]{διʼ }[αἰ]{θέ}[ρος,]'
#       Extracted syllables: '[ἄλ]{λο }[θαλ]{πνό}{τε}{ρον }{ἐν }[ἁ]{μέ}[ρᾳ ]{φα}[εν]{νὸν }[ἄ]{στρον }{ἐ}[ρή][μας ]{διʼ }[αἰ]{θέ}[ρος,]'
#       Child line 7: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='μηδʼ'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='Ὀ'
#           Span: classes=['syll', 'long'], content='λυμ'
#           Span: classes=['syll', 'short'], content='πί'
#           Span: classes=['syll', 'long'], content='ας'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='γῶ'
#           Span: classes=['syll', 'short'], content='να'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='φέρ'
#           Span: classes=['syll', 'short'], content='τε'
#           Span: classes=['syll', 'short'], content='ρον'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'long'], content='αὐ'
#           Span: classes=['syll', 'long'], content='δά'
#           Span: classes=['syll', 'short'], content='σο'
#           Span: classes=['syll', 'long', 'worddiv'], content='μεν·'
#       Final result: '[μηδʼ ]{Ὀ}[λυμ]{πί}[ας ]{ἀ}[γῶ]{να }[φέρ]{τε}{ρον }[αὐ][δά]{σο}[μεν·]'
#       Extracted syllables: '[μηδʼ ]{Ὀ}[λυμ]{πί}[ας ]{ἀ}[γῶ]{να }[φέρ]{τε}{ρον }[αὐ][δά]{σο}[μεν·]'
#       Child line 8: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='ὅ'
#           Span: classes=['syll', 'short'], content='θεν'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='ὁ'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'short'], content='πο'
#           Span: classes=['syll', 'short'], content='λύ'
#           Span: classes=['syll', 'short'], content='φα'
#           Span: classes=['syll', 'short'], content='τος'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='ὕ'
#           Span: classes=['syll', 'short'], content='μνος'
#         Word 5: 5 sylls
#           Span: classes=['syll', 'long'], content='ἀμ'
#           Span: classes=['syll', 'short'], content='φι'
#           Span: classes=['syll', 'long'], content='βάλ'
#           Span: classes=['syll', 'short'], content='λε'
#           Span: classes=['syll', 'long', 'worddiv'], content='ται'
#       Final result: '{ὅ}{θεν }{ὁ }{πο}{λύ}{φα}{τος }[ὕ]{μνος }[ἀμ]{φι}[βάλ]{λε}[ται]'
#       Extracted syllables: '{ὅ}{θεν }{ὁ }{πο}{λύ}{φα}{τος }[ὕ]{μνος }[ἀμ]{φι}[βάλ]{λε}[ται]'
#       Child line 9: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='σο'
#           Span: classes=['syll', 'long', 'unres'], content='φῶν'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'long'], content='μη'
#           Span: classes=['syll', 'short'], content='τί'
#           Span: classes=['syll', 'long'], content='εσ'
#           Span: classes=['syll', 'short'], content='σι,'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='κε'
#           Span: classes=['syll', 'short'], content='λα'
#           Span: classes=['syll', 'long', 'worddiv'], content='δεῖν'
#       Final result: '{σο}[φῶν ][μη]{τί}[εσ]{σι, }{κε}{λα}[δεῖν]'
#       Extracted syllables: '{σο}[φῶν ][μη]{τί}[εσ]{σι, }{κε}{λα}[δεῖν]'
#       Child line 10: classes ['line', 'checked', 'fifth']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='Κρό'
#           Span: classes=['syll', 'long'], content='νου'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long'], content='παῖδʼ'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='ἐς'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='ἀφ'
#           Span: classes=['syll', 'short'], content='νε'
#           Span: classes=['syll', 'long'], content='ὰν'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'short'], content='ἱ'
#           Span: classes=['syll', 'short'], content='κο'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='νους'
#       Final result: '{Κρό}[νου ][παῖδʼ ]{ἐς }[ἀφ]{νε}[ὰν ]{ἱ}{κο}{μέ}[νους]'
#       Extracted syllables: '{Κρό}[νου ][παῖδʼ ]{ἐς }[ἀφ]{νε}[ὰν ]{ἱ}{κο}{μέ}[νους]'
#       Child line 11: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'short'], content='μά'
#           Span: classes=['syll', 'long'], content='και'
#           Span: classes=['syll', 'short'], content='ραν'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='Ἱ'
#           Span: classes=['syll', 'short'], content='έ'
#           Span: classes=['syll', 'long'], content='ρω'
#           Span: classes=['syll', 'short'], content='νος'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='ἑ'
#           Span: classes=['syll', 'short'], content='στί'
#           Span: classes=['syll', 'long', 'worddiv'], content='αν,'
#       Final result: '{μά}[και]{ραν }{Ἱ}{έ}[ρω]{νος }[ἑ]{στί}[αν,]'
#       Extracted syllables: '{μά}[και]{ραν }{Ἱ}{έ}[ρω]{νος }[ἑ]{στί}[αν,]'
#     Total lines collected: 11
#   Strophe 2: type='Antistrophe', num='1'
#   Classes: ['strophe']
#     Processing as key: antistrophe_1
#     Found 12 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 11 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'short'], content='θε'
#           Span: classes=['syll', 'long'], content='μι'
#           Span: classes=['syll', 'long'], content='στεῖ'
#           Span: classes=['syll', 'short'], content='ον'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='ὃς'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='ἀμ'
#           Span: classes=['syll', 'short'], content='φέ'
#           Span: classes=['syll', 'long'], content='πει'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='σκᾶ'
#           Span: classes=['syll', 'short'], content='πτον'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long'], content='ἐν'
#         Word 6: 4 sylls
#           Span: classes=['syll', 'short'], content='πο'
#           Span: classes=['syll', 'short'], content='λυ'
#           Span: classes=['syll', 'long'], content='μά'
#           Span: classes=['syll', 'long', 'worddiv'], content='λῳ'
#       Final result: '{θε}[μι][στεῖ]{ον }{ὃς }[ἀμ]{φέ}[πει ][σκᾶ]{πτον }[ἐν ]{πο}{λυ}[μά][λῳ]'
#       Extracted syllables: '{θε}[μι][στεῖ]{ον }{ὃς }[ἀμ]{φέ}[πει ][σκᾶ]{πτον }[ἐν ]{πο}{λυ}[μά][λῳ]'
#       Child line 2: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'short'], content='Σι'
#           Span: classes=['syll', 'short'], content='κε'
#           Span: classes=['syll', 'short'], content='λί'
#           Span: classes=['syll', 'long'], content='ᾳ,'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='δρέ'
#           Span: classes=['syll', 'long'], content='πων'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long'], content='μὲν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='κο'
#           Span: classes=['syll', 'short'], content='ρυ'
#           Span: classes=['syll', 'long'], content='φὰς'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'short'], content='ρε'
#           Span: classes=['syll', 'long'], content='τᾶν'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='ἄ'
#           Span: classes=['syll', 'short'], content='πο'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long'], content='πα'
#           Span: classes=['syll', 'long', 'worddiv'], content='σᾶν,'
#       Final result: '{Σι}{κε}{λί}[ᾳ, ]{δρέ}[πων ][μὲν ]{κο}{ρυ}[φὰς ]{ἀ}{ρε}[τᾶν ]{ἄ}{πο }[πα][σᾶν,]'
#       Extracted syllables: '{Σι}{κε}{λί}[ᾳ, ]{δρέ}[πων ][μὲν ]{κο}{ρυ}[φὰς ]{ἀ}{ρε}[τᾶν ]{ἄ}{πο }[πα][σᾶν,]'
#       Child line 3: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 5 sylls
#           Span: classes=['syll', 'long'], content='ἀ'
#           Span: classes=['syll', 'short'], content='γλα'
#           Span: classes=['syll', 'long'], content='ΐ'
#           Span: classes=['syll', 'short'], content='ζε'
#           Span: classes=['syll', 'long'], content='ται'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='δὲ'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='καὶ'
#       Final result: '[ἀ]{γλα}[ΐ]{ζε}[ται ]{δὲ }[καὶ]'
#       Extracted syllables: '[ἀ]{γλα}[ΐ]{ζε}[ται ]{δὲ }[καὶ]'
#       Child line 4: classes ['line', 'checked', 'fifth']
#       Found 3 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='μου'
#           Span: classes=['syll', 'short'], content='σι'
#           Span: classes=['syll', 'long'], content='κᾶς'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='ἐν'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='ώ'
#           Span: classes=['syll', 'long', 'worddiv'], content='τῳ,'
#       Final result: '[μου]{σι}[κᾶς ]{ἐν }{ἀ}[ώ][τῳ,]'
#       Extracted syllables: '[μου]{σι}[κᾶς ]{ἐν }{ἀ}[ώ][τῳ,]'
#       Child line 5: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='οἷ'
#           Span: classes=['syll', 'short'], content='α'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='παί'
#           Span: classes=['syll', 'short'], content='ζο'
#           Span: classes=['syll', 'long'], content='μεν'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='φί'
#           Span: classes=['syll', 'long', 'worddiv'], content='λαν'
#       Final result: '[οἷ]{α }[παί]{ζο}[μεν ]{φί}[λαν]'
#       Extracted syllables: '[οἷ]{α }[παί]{ζο}[μεν ]{φί}[λαν]'
#       Child line 6: classes ['line', 'checked']
#       Found 9 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='ἄν'
#           Span: classes=['syll', 'short'], content='δρες'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='ἀμ'
#           Span: classes=['syll', 'short'], content='φὶ'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='θα'
#           Span: classes=['syll', 'short'], content='μὰ'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='τρά'
#           Span: classes=['syll', 'long'], content='πε'
#           Span: classes=['syll', 'short'], content='ζαν.'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long'], content='ἀλ'
#           Span: classes=['syll', 'short'], content='λὰ'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'long'], content='Δω'
#           Span: classes=['syll', 'short'], content='ρί'
#           Span: classes=['syll', 'long'], content='αν'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'short'], content='πὸ'
#         Word 8: 3 sylls
#           Span: classes=['syll', 'long'], content='φόρ'
#           Span: classes=['syll', 'long'], content='μιγ'
#           Span: classes=['syll', 'short'], content='γα'
#         Word 9: 3 sylls
#           Span: classes=['syll', 'long'], content='πασ'
#           Span: classes=['syll', 'short'], content='σά'
#           Span: classes=['syll', 'long', 'worddiv'], content='λου'
#       Final result: '[ἄν]{δρες }[ἀμ]{φὶ }{θα}{μὰ }{τρά}[πε]{ζαν. }[ἀλ]{λὰ }[Δω]{ρί}[αν ]{ἀ}{πὸ }[φόρ][μιγ]{γα }[πασ]{σά}[λου]'
#       Extracted syllables: '[ἄν]{δρες }[ἀμ]{φὶ }{θα}{μὰ }{τρά}[πε]{ζαν. }[ἀλ]{λὰ }[Δω]{ρί}[αν ]{ἀ}{πὸ }[φόρ][μιγ]{γα }[πασ]{σά}[λου]'
#       Child line 7: classes ['line', 'checked']
#       Found 9 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='λάμ'
#           Span: classes=['syll', 'short'], content='βανʼ,'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long'], content='εἴ'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='τί'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long'], content='τοι'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'short'], content='Πί'
#           Span: classes=['syll', 'long'], content='σας'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'short'], content='τε'
#         Word 7: 1 sylls
#           Span: classes=['syll', 'long'], content='καὶ'
#         Word 8: 4 sylls
#           Span: classes=['syll', 'short'], content='Φε'
#           Span: classes=['syll', 'short'], content='ρε'
#           Span: classes=['syll', 'long'], content='νί'
#           Span: classes=['syll', 'long'], content='κου'
#         Word 9: 2 sylls
#           Span: classes=['syll', 'short'], content='χά'
#           Span: classes=['syll', 'long', 'worddiv'], content='ρις'
#       Final result: '[λάμ]{βανʼ, }[εἴ ]{τί }[τοι ]{Πί}[σας ]{τε }[καὶ ]{Φε}{ρε}[νί][κου ]{χά}[ρις]'
#       Extracted syllables: '[λάμ]{βανʼ, }[εἴ ]{τί }[τοι ]{Πί}[σας ]{τε }[καὶ ]{Φε}{ρε}[νί][κου ]{χά}[ρις]'
#       Child line 8: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='νό'
#           Span: classes=['syll', 'short'], content='ον'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='ὑ'
#           Span: classes=['syll', 'short'], content='πὸ'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'short'], content='γλυ'
#           Span: classes=['syll', 'short'], content='κυ'
#           Span: classes=['syll', 'short'], content='τά'
#           Span: classes=['syll', 'long'], content='ταις'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='ἔ'
#           Span: classes=['syll', 'long'], content='θη'
#           Span: classes=['syll', 'short'], content='κε'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'long'], content='φρον'
#           Span: classes=['syll', 'short'], content='τί'
#           Span: classes=['syll', 'long', 'worddiv'], content='σιν,'
#       Final result: '{νό}{ον }{ὑ}{πὸ }{γλυ}{κυ}{τά}[ταις ]{ἔ}[θη]{κε }[φρον]{τί}[σιν,]'
#       Extracted syllables: '{νό}{ον }{ὑ}{πὸ }{γλυ}{κυ}{τά}[ταις ]{ἔ}[θη]{κε }[φρον]{τί}[σιν,]'
#       Child line 9: classes ['line', 'checked', 'fifth']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='ὅ'
#           Span: classes=['syll', 'short', 'resolved', 'res1'], content='τε'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short', 'resolved', 'res2'], content='παρʼ'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='Ἀλ'
#           Span: classes=['syll', 'short'], content='φε'
#           Span: classes=['syll', 'long'], content='ῷ'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='σύ'
#           Span: classes=['syll', 'short'], content='το,'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'short'], content='δέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='μας'
#       Final result: '{ὅ}{€τε }{€παρʼ }[Ἀλ]{φε}[ῷ ]{σύ}{το, }{δέ}[μας]'
#       Extracted syllables: '{ὅ}{€τε }{€παρʼ }[Ἀλ]{φε}[ῷ ]{σύ}{το, }{δέ}[μας]'
#       Child line 10: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='κέν'
#           Span: classes=['syll', 'long'], content='τη'
#           Span: classes=['syll', 'short'], content='τον'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long'], content='ἐν'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='δρό'
#           Span: classes=['syll', 'long'], content='μοι'
#           Span: classes=['syll', 'short'], content='σι'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='πα'
#           Span: classes=['syll', 'short'], content='ρέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='χων,'
#       Final result: '{ἀ}[κέν][τη]{τον }[ἐν ]{δρό}[μοι]{σι }{πα}{ρέ}[χων,]'
#       Extracted syllables: '{ἀ}[κέν][τη]{τον }[ἐν ]{δρό}[μοι]{σι }{πα}{ρέ}[χων,]'
#       Child line 11: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='κρά'
#           Span: classes=['syll', 'long'], content='τει'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='δὲ'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'short'], content='προ'
#           Span: classes=['syll', 'short'], content='σέ'
#           Span: classes=['syll', 'long'], content='μι'
#           Span: classes=['syll', 'short'], content='ξε'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='δε'
#           Span: classes=['syll', 'short'], content='σπό'
#           Span: classes=['syll', 'long', 'worddiv'], content='ταν,'
#       Final result: '{κρά}[τει ]{δὲ }{προ}{σέ}[μι]{ξε }[δε]{σπό}[ταν,]'
#       Extracted syllables: '{κρά}[τει ]{δὲ }{προ}{σέ}[μι]{ξε }[δε]{σπό}[ταν,]'
#     Total lines collected: 11
#   Strophe 3: type='Epode', num='1'
#   Classes: ['Epode']
#     Processing as key: epode_1
#     Found 9 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#     Found 8 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 5 sylls
#           Span: classes=['syll', 'short'], content='Συ'
#           Span: classes=['syll', 'long'], content='ρα'
#           Span: classes=['syll', 'short'], content='κό'
#           Span: classes=['syll', 'short'], content='σι'
#           Span: classes=['syll', 'short'], content='ον'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'long'], content='ἱπ'
#           Span: classes=['syll', 'short'], content='πο'
#           Span: classes=['syll', 'long'], content='χάρ'
#           Span: classes=['syll', 'long'], content='μαν'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'short'], content='βα'
#           Span: classes=['syll', 'short'], content='σι'
#           Span: classes=['syll', 'long'], content='λῆ'
#           Span: classes=['syll', 'short', 'worddiv'], content='α.'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='λάμ'
#           Span: classes=['syll', 'long'], content='πει'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'short'], content='δέ'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'long'], content='οἱ'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='κλέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='ος'
#       Final result: '{Συ}[ρα]{κό}{σι}{ον }[ἱπ]{πο}[χάρ][μαν ]{βα}{σι}[λῆ]{α. }[λάμ][πει ]{δέ }[οἱ ]{κλέ}[ος]'
#       Extracted syllables: '{Συ}[ρα]{κό}{σι}{ον }[ἱπ]{πο}[χάρ][μαν ]{βα}{σι}[λῆ]{α. }[λάμ][πει ]{δέ }[οἱ ]{κλέ}[ος]'
#       Child line 2: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'short'], content='ἐν'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'long'], content='εὐ'
#           Span: classes=['syll', 'long'], content='ά'
#           Span: classes=['syll', 'short'], content='νο'
#           Span: classes=['syll', 'short'], content='ρι'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='Λυ'
#           Span: classes=['syll', 'long', 'worddiv'], content='δοῦ'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='Πέ'
#           Span: classes=['syll', 'short'], content='λο'
#           Span: classes=['syll', 'short', 'worddiv'], content='πος'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='ποι'
#           Span: classes=['syll', 'short'], content='κί'
#           Span: classes=['syll', 'long', 'worddiv'], content='ᾳ·'
#       Final result: '{ἐν }[εὐ][ά]{νο}{ρι }[Λυ][δοῦ ]{Πέ}{λο}{πος }{ἀ}[ποι]{κί}[ᾳ·]'
#       Extracted syllables: '{ἐν }[εὐ][ά]{νο}{ρι }[Λυ][δοῦ ]{Πέ}{λο}{πος }{ἀ}[ποι]{κί}[ᾳ·]'
#       Child line 3: classes ['line', 'checked', 'fifth']
#       Found 4 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='τοῦ'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long'], content='γα'
#           Span: classes=['syll', 'short'], content='σθε'
#           Span: classes=['syll', 'long'], content='νὴς'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'long'], content='ράσ'
#           Span: classes=['syll', 'short'], content='σα'
#           Span: classes=['syll', 'short'], content='το'
#         Word 4: 4 sylls
#           Span: classes=['syll', 'long'], content='γαι'
#           Span: classes=['syll', 'long'], content='ά'
#           Span: classes=['syll', 'short'], content='ο'
#           Span: classes=['syll', 'long', 'worddiv'], content='χος'
#       Final result: '[τοῦ ]{με}[γα]{σθε}[νὴς ]{ἐ}[ράσ]{σα}{το }[γαι][ά]{ο}[χος]'
#       Extracted syllables: '[τοῦ ]{με}[γα]{σθε}[νὴς ]{ἐ}[ράσ]{σα}{το }[γαι][ά]{ο}[χος]'
#       Child line 4: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'short'], content='Πο'
#           Span: classes=['syll', 'long'], content='σει'
#           Span: classes=['syll', 'long'], content='δᾶν,'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'long'], content='πεί'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long'], content='νιν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='κα'
#           Span: classes=['syll', 'short'], content='θα'
#           Span: classes=['syll', 'long'], content='ροῦ'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='λέ'
#           Span: classes=['syll', 'long'], content='βη'
#           Span: classes=['syll', 'short'], content='τος'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'long'], content='ἔ'
#           Span: classes=['syll', 'short'], content='ξε'
#           Span: classes=['syll', 'short'], content='λε'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long'], content='Κλω'
#           Span: classes=['syll', 'long', 'worddiv'], content='θὼ'
#       Final result: '{Πο}[σει][δᾶν, ]{ἐ}[πεί ][νιν ]{κα}{θα}[ροῦ ]{λέ}[βη]{τος }[ἔ]{ξε}{λε }[Κλω][θὼ]'
#       Extracted syllables: '{Πο}[σει][δᾶν, ]{ἐ}[πεί ][νιν ]{κα}{θα}[ροῦ ]{λέ}[βη]{τος }[ἔ]{ξε}{λε }[Κλω][θὼ]'
#       Child line 5: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'short'], content='λέ'
#           Span: classes=['syll', 'long'], content='φαν'
#           Span: classes=['syll', 'short'], content='τι'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='φαί'
#           Span: classes=['syll', 'short'], content='δι'
#           Span: classes=['syll', 'short'], content='μον'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='ὦ'
#           Span: classes=['syll', 'long'], content='μον'
#         Word 4: 4 sylls
#           Span: classes=['syll', 'short'], content='κε'
#           Span: classes=['syll', 'long'], content='καδ'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='νον.'
#       Final result: '{ἐ}{λέ}[φαν]{τι }[φαί]{δι}{μον }[ὦ][μον ]{κε}[καδ]{μέ}[νον.]'
#       Extracted syllables: '{ἐ}{λέ}[φαν]{τι }[φαί]{δι}{μον }[ὦ][μον ]{κε}[καδ]{μέ}[νον.]'
#       Child line 6: classes ['line', 'checked']
#       Found 8 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='ἦ'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='θαυ'
#           Span: classes=['syll', 'short'], content='μα'
#           Span: classes=['syll', 'short'], content='τὰ'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='πολ'
#           Span: classes=['syll', 'short'], content='λά,'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long'], content='καί'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='πού'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'short'], content='τι'
#         Word 7: 1 sylls
#           Span: classes=['syll', 'long'], content='καὶ'
#         Word 8: 2 sylls
#           Span: classes=['syll', 'short'], content='βρο'
#           Span: classes=['syll', 'long', 'worddiv'], content='τῶν'
#       Final result: '[ἦ ][θαυ]{μα}{τὰ }[πολ]{λά, }[καί ][πού ]{τι }[καὶ ]{βρο}[τῶν]'
#       Extracted syllables: '[ἦ ][θαυ]{μα}{τὰ }[πολ]{λά, }[καί ][πού ]{τι }[καὶ ]{βρο}[τῶν]'
#       Child line 7: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='φά'
#           Span: classes=['syll', 'short'], content='τις'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'short'], content='ὑ'
#           Span: classes=['syll', 'long'], content='πὲρ'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='τὸν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='λα'
#           Span: classes=['syll', 'long'], content='θῆ'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'short'], content='λό'
#           Span: classes=['syll', 'long', 'worddiv'], content='γον'
#       Final result: '{φά}{τις }{ὑ}[πὲρ ]{τὸν }{ἀ}[λα][θῆ ]{λό}[γον]'
#       Extracted syllables: '{φά}{τις }{ὑ}[πὲρ ]{τὸν }{ἀ}[λα][θῆ ]{λό}[γον]'
#       Child line 8: classes ['line', 'checked', 'fifth']
#       Found 5 word spans
#         Word 1: 5 sylls
#           Span: classes=['syll', 'short'], content='δε'
#           Span: classes=['syll', 'long'], content='δαι'
#           Span: classes=['syll', 'long'], content='δαλ'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long'], content='νοι'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='ψεύ'
#           Span: classes=['syll', 'short'], content='δε'
#           Span: classes=['syll', 'short'], content='σι'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='ποι'
#           Span: classes=['syll', 'short'], content='κί'
#           Span: classes=['syll', 'long'], content='λοις'
#         Word 4: 5 sylls
#           Span: classes=['syll', 'long'], content='ἐ'
#           Span: classes=['syll', 'short'], content='ξα'
#           Span: classes=['syll', 'short'], content='πα'
#           Span: classes=['syll', 'long'], content='τῶν'
#           Span: classes=['syll', 'short'], content='τι'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long'], content='μῦ'
#           Span: classes=['syll', 'long', 'worddiv'], content='θοι'
#       Final result: '{δε}[δαι][δαλ]{μέ}[νοι ][ψεύ]{δε}{σι }[ποι]{κί}[λοις ][ἐ]{ξα}{πα}[τῶν]{τι }[μῦ][θοι]'
#       Extracted syllables: '{δε}[δαι][δαλ]{μέ}[νοι ][ψεύ]{δε}{σι }[ποι]{κί}[λοις ][ἐ]{ξα}{πα}[τῶν]{τι }[μῦ][θοι]'
#     Total lines collected: 8
#   Strophe 4: type='Strophe', num='2'
#   Classes: ['strophe']
#     Processing as key: strophe_2
#     Found 12 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 11 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='Χά'
#           Span: classes=['syll', 'long'], content='ρις'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='δ᾽,ἅ'
#           Span: classes=['syll', 'short'], content='περ'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='ἅ'
#           Span: classes=['syll', 'long'], content='παν'
#           Span: classes=['syll', 'short'], content='τα'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='τεύ'
#           Span: classes=['syll', 'long'], content='χει'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'short'], content='τὰ'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'long'], content='μεί'
#           Span: classes=['syll', 'short'], content='λι'
#           Span: classes=['syll', 'short'], content='χα'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'long'], content='θνα'
#           Span: classes=['syll', 'long', 'worddiv'], content='τοῖς,'
#       Final result: '{Χά}[ρις ][δ᾽,ἅ]{περ }{ἅ}[παν]{τα }[τεύ][χει ]{τὰ }[μεί]{λι}{χα }[θνα][τοῖς,]'
#       Extracted syllables: '{Χά}[ρις ][δ᾽,ἅ]{περ }{ἅ}[παν]{τα }[τεύ][χει ]{τὰ }[μεί]{λι}{χα }[θνα][τοῖς,]'
#       Child line 2: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 5 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'short'], content='πι'
#           Span: classes=['syll', 'short'], content='φέ'
#           Span: classes=['syll', 'long'], content='ροι'
#           Span: classes=['syll', 'short'], content='σα'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='τι'
#           Span: classes=['syll', 'long'], content='μὰν'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='καὶ'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='ἄ'
#           Span: classes=['syll', 'long'], content='πι'
#           Span: classes=['syll', 'short'], content='στον'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'long'], content='μή'
#           Span: classes=['syll', 'short'], content='σα'
#           Span: classes=['syll', 'short'], content='το'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'long'], content='πι'
#           Span: classes=['syll', 'long', 'worddiv'], content='στὸν'
#       Final result: '{ἐ}{πι}{φέ}[ροι]{σα }[τι][μὰν ]{καὶ }{ἄ}[πι]{στον }{ἐ}[μή]{σα}{το }[πι][στὸν]'
#       Extracted syllables: '{ἐ}{πι}{φέ}[ροι]{σα }[τι][μὰν ]{καὶ }{ἄ}[πι]{στον }{ἐ}[μή]{σα}{το }[πι][στὸν]'
#       Child line 3: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='ἔμ'
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long'], content='ναι'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='τὸ'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='πολ'
#           Span: classes=['syll', 'short'], content='λά'
#           Span: classes=['syll', 'long', 'worddiv'], content='κις·'
#       Final result: '[ἔμ]{με}[ναι ]{τὸ }[πολ]{λά}[κις·]'
#       Extracted syllables: '[ἔμ]{με}[ναι ]{τὸ }[πολ]{λά}[κις·]'
#       Child line 4: classes ['line', 'checked']
#       Found 2 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='ἁ'
#           Span: classes=['syll', 'short'], content='μέ'
#           Span: classes=['syll', 'long'], content='ραι'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='δ᾽ἐ'
#           Span: classes=['syll', 'short'], content='πί'
#           Span: classes=['syll', 'long'], content='λοι'
#           Span: classes=['syll', 'long', 'worddiv'], content='ποι'
#       Final result: '[ἁ]{μέ}[ραι ]{δ᾽ἐ}{πί}[λοι][ποι]'
#       Extracted syllables: '[ἁ]{μέ}[ραι ]{δ᾽ἐ}{πί}[λοι][ποι]'
#       Child line 5: classes ['line', 'checked', 'fifth']
#       Found 2 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='μάρ'
#           Span: classes=['syll', 'short'], content='τυ'
#           Span: classes=['syll', 'long'], content='ρες'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='σο'
#           Span: classes=['syll', 'long'], content='φώ'
#           Span: classes=['syll', 'short'], content='τα'
#           Span: classes=['syll', 'long', 'worddiv'], content='τοι.'
#       Final result: '[μάρ]{τυ}[ρες ]{σο}[φώ]{τα}[τοι.]'
#       Extracted syllables: '[μάρ]{τυ}[ρες ]{σο}[φώ]{τα}[τοι.]'
#       Child line 6: classes ['line', 'checked']
#       Found 10 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='ἔ'
#           Span: classes=['syll', 'short'], content='στι'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='δ᾽ἀν'
#           Span: classes=['syll', 'short'], content='δρὶ'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='φά'
#           Span: classes=['syll', 'short'], content='μεν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'long'], content='οι'
#           Span: classes=['syll', 'short'], content='κὸς'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long'], content='ἀμ'
#           Span: classes=['syll', 'short'], content='φὶ'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'long'], content='δαι'
#           Span: classes=['syll', 'short'], content='μό'
#           Span: classes=['syll', 'long'], content='νων'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='κα'
#           Span: classes=['syll', 'short'], content='λά·'
#         Word 8: 2 sylls
#           Span: classes=['syll', 'long'], content='μεί'
#           Span: classes=['syll', 'long'], content='ων'
#         Word 9: 1 sylls
#           Span: classes=['syll', 'short'], content='γὰρ'
#         Word 10: 3 sylls
#           Span: classes=['syll', 'long'], content='αἰ'
#           Span: classes=['syll', 'short'], content='τί'
#           Span: classes=['syll', 'long', 'worddiv'], content='α.'
#       Final result: '[ἔ]{στι }[δ᾽ἀν]{δρὶ }{φά}{μεν }{ἐ}[οι]{κὸς }[ἀμ]{φὶ }[δαι]{μό}[νων ]{κα}{λά· }[μεί][ων ]{γὰρ }[αἰ]{τί}[α.]'
#       Extracted syllables: '[ἔ]{στι }[δ᾽ἀν]{δρὶ }{φά}{μεν }{ἐ}[οι]{κὸς }[ἀμ]{φὶ }[δαι]{μό}[νων ]{κα}{λά· }[μεί][ων ]{γὰρ }[αἰ]{τί}[α.]'
#       Child line 7: classes ['line', 'checked']
#       Found 6 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='υἱ'
#           Span: classes=['syll', 'short'], content='ὲ'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='Ταν'
#           Span: classes=['syll', 'short'], content='τά'
#           Span: classes=['syll', 'long'], content='λου,'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'short'], content='σὲ'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'long'], content='δ᾽,ἀν'
#           Span: classes=['syll', 'short'], content='τί'
#           Span: classes=['syll', 'long'], content='α'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='προ'
#           Span: classes=['syll', 'short'], content='τέ'
#           Span: classes=['syll', 'long'], content='ρων,'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'long'], content='φθέγ'
#           Span: classes=['syll', 'short'], content='ξο'
#           Span: classes=['syll', 'long', 'worddiv'], content='μαι,'
#       Final result: '[υἱ]{ὲ }[Ταν]{τά}[λου, ]{σὲ }[δ᾽,ἀν]{τί}[α ]{προ}{τέ}[ρων, ][φθέγ]{ξο}[μαι,]'
#       Extracted syllables: '[υἱ]{ὲ }[Ταν]{τά}[λου, ]{σὲ }[δ᾽,ἀν]{τί}[α ]{προ}{τέ}[ρων, ][φθέγ]{ξο}[μαι,]'
#       Child line 8: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'short'], content='ὁ'
#           Span: classes=['syll', 'short'], content='πότʼ'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'short'], content='κά'
#           Span: classes=['syll', 'short'], content='λε'
#           Span: classes=['syll', 'short'], content='σε'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='πα'
#           Span: classes=['syll', 'long'], content='τὴρ'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='τὸν'
#         Word 5: 5 sylls
#           Span: classes=['syll', 'long'], content='εὐ'
#           Span: classes=['syll', 'short'], content='νο'
#           Span: classes=['syll', 'long'], content='μώ'
#           Span: classes=['syll', 'short'], content='τα'
#           Span: classes=['syll', 'long', 'worddiv'], content='τον'
#       Final result: '{ὁ}{πότʼ }{ἐ}{κά}{λε}{σε }{πα}[τὴρ ]{τὸν }[εὐ]{νο}[μώ]{τα}[τον]'
#       Extracted syllables: '{ὁ}{πότʼ }{ἐ}{κά}{λε}{σε }{πα}[τὴρ ]{τὸν }[εὐ]{νο}[μώ]{τα}[τον]'
#       Child line 9: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'short'], content='ἐς'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short', 'resolved', 'res1'], content='ἔ'
#           Span: classes=['syll', 'short', 'resolved', 'res2'], content='ρα'
#           Span: classes=['syll', 'long'], content='νον'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='φί'
#           Span: classes=['syll', 'long'], content='λαν'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short'], content='τε'
#         Word 5: 3 sylls
#           Span: classes=['syll', 'short'], content='Σί'
#           Span: classes=['syll', 'short'], content='πυ'
#           Span: classes=['syll', 'long', 'worddiv'], content='λον,'
#       Final result: '{ἐς }{€ἔ}{€ρα}[νον ]{φί}[λαν ]{τε }{Σί}{πυ}[λον,]'
#       Extracted syllables: '{ἐς }{€ἔ}{€ρα}[νον ]{φί}[λαν ]{τε }{Σί}{πυ}[λον,]'
#       Child line 10: classes ['line', 'checked', 'fifth']
#       Found 4 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='μοι'
#           Span: classes=['syll', 'long'], content='βαῖ'
#           Span: classes=['syll', 'short'], content='α'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='θεοῖ'
#           Span: classes=['syll', 'short'], content='σι'
#         Word 3: 2 sylls
# ...
#           Span: classes=['syll', 'long'], content='ον'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='σέ'
#           Span: classes=['syll', 'long'], content='βον'
#           Span: classes=['syll', 'short'], content='τι'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='πα'
#           Span: classes=['syll', 'short'], content='τρὸς'
#         Word 4: 5 sylls
#           Span: classes=['syll', 'short'], content='Ὀ'
#           Span: classes=['syll', 'long'], content='λυμ'
#           Span: classes=['syll', 'short'], content='πί'
#           Span: classes=['syll', 'long'], content='οι'
#           Span: classes=['syll', 'short', 'worddiv'], content='ο'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long'], content='τι'
#           Span: classes=['syll', 'long', 'worddiv'], content='μάν.'
#       Final result: '[αἰ]{έ}{να}[ον ]{σέ}[βον]{τι }[πα]{τρὸς }{Ὀ}[λυμ]{πί}[οι]{ο }[τι][μάν.]'
#       Extracted syllables: '[αἰ]{έ}{να}[ον ]{σέ}[βον]{τι }[πα]{τρὸς }{Ὀ}[λυμ]{πί}[οι]{ο }[τι][μάν.]'
#     Total lines collected: 12
#   Strophe 2: type='Strophe', num='2'
#   Classes: ['strophe']
#     Processing as key: strophe_2
#     Found 13 total child divs
#       Checking div with classes: ['stropheheader']
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked', 'fifth']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#       Checking div with classes: ['line', 'checked']
#         -> This is a line div!
#     Found 12 child line divs
#       Child line 1: classes ['line', 'checked']
#       Found 3 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='ὦ'
#         Word 2: 2 sylls
#           Span: classes=['syll', 'long'], content='πότ'
#           Span: classes=['syll', 'short'], content='νιʼ'
#         Word 3: 4 sylls
#           Span: classes=['syll', 'long'], content='Ἀ'
#           Span: classes=['syll', 'short'], content='γλα'
#           Span: classes=['syll', 'short'], content='ΐ'
#           Span: classes=['syll', 'long', 'worddiv'], content='α'
#       Final result: '[ὦ ][πότ]{νιʼ }[Ἀ]{γλα}{ΐ}[α]'
#       Extracted syllables: '[ὦ ][πότ]{νιʼ }[Ἀ]{γλα}{ΐ}[α]'
#       Child line 2: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 5 sylls
#           Span: classes=['syll', 'short'], content='φι'
#           Span: classes=['syll', 'long'], content='λη'
#           Span: classes=['syll', 'short'], content='σί'
#           Span: classes=['syll', 'long'], content='μολ'
#           Span: classes=['syll', 'short', 'worddiv'], content='πέ'
#         Word 2: 4 sylls
#           Span: classes=['syll', 'long'], content='τ᾽Εὐ'
#           Span: classes=['syll', 'short'], content='φρο'
#           Span: classes=['syll', 'short'], content='σύ'
#           Span: classes=['syll', 'long'], content='να,'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='θε'
#           Span: classes=['syll', 'long'], content='ῶν'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='κρα'
#           Span: classes=['syll', 'long'], content='τί'
#           Span: classes=['syll', 'long', 'worddiv'], content='στου'
#       Final result: '{φι}[λη]{σί}[μολ]{πέ }[τ᾽Εὐ]{φρο}{σύ}[να, ]{θε}[ῶν ]{κρα}[τί][στου]'
#       Extracted syllables: '{φι}[λη]{σί}[μολ]{πέ }[τ᾽Εὐ]{φρο}{σύ}[να, ]{θε}[ῶν ]{κρα}[τί][στου]'
#       Child line 3: classes ['line', 'checked', 'fifth']
#       Found 5 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='παῖ'
#           Span: classes=['syll', 'short'], content='δες,'
#         Word 2: 5 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'long'], content='πα'
#           Span: classes=['syll', 'short'], content='κο'
#           Span: classes=['syll', 'long'], content='οῖ'
#           Span: classes=['syll', 'short'], content='τε'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='νῦν,'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='Θα'
#           Span: classes=['syll', 'short'], content='λί'
#           Span: classes=['syll', 'long'], content='α'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='τε'
#       Final result: '[παῖ]{δες, }{ἐ}[πα]{κο}[οῖ]{τε }[νῦν, ]{Θα}{λί}[α ][τε]'
#       Extracted syllables: '[παῖ]{δες, }{ἐ}[πα]{κο}[οῖ]{τε }[νῦν, ]{Θα}{λί}[α ][τε]'
#       Child line 4: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 5 sylls
#           Span: classes=['syll', 'short'], content='ἐ'
#           Span: classes=['syll', 'short'], content='ρα'
#           Span: classes=['syll', 'short'], content='σί'
#           Span: classes=['syll', 'long'], content='μολ'
#           Span: classes=['syll', 'short'], content='πε,'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='ἰ'
#           Span: classes=['syll', 'long'], content='δοῖ'
#           Span: classes=['syll', 'short'], content='σα'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='τόν'
#           Span: classes=['syll', 'short'], content='δε'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='κῶ'
#           Span: classes=['syll', 'short'], content='μον'
#         Word 5: 1 sylls
#           Span: classes=['syll', 'short'], content='ἐπʼ'
#         Word 6: 3 sylls
#           Span: classes=['syll', 'long'], content='εὐ'
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'long'], content='νεῖ'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='τύ'
#           Span: classes=['syll', 'long', 'worddiv'], content='χᾳ'
#       Final result: '{ἐ}{ρα}{σί}[μολ]{πε, }{ἰ}[δοῖ]{σα }[τόν]{δε }[κῶ]{μον }{ἐπʼ }[εὐ]{με}[νεῖ ]{τύ}[χᾳ]'
#       Extracted syllables: '{ἐ}{ρα}{σί}[μολ]{πε, }{ἰ}[δοῖ]{σα }[τόν]{δε }[κῶ]{μον }{ἐπʼ }[εὐ]{με}[νεῖ ]{τύ}[χᾳ]'
#       Child line 5: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='κοῦ'
#           Span: classes=['syll', 'short'], content='φα'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='βι'
#           Span: classes=['syll', 'long'], content='βῶν'
#           Span: classes=['syll', 'short'], content='τα·'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='Λυ'
#           Span: classes=['syll', 'long', 'worddiv'], content='δῷ'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'short', 'worddiv'], content='γὰρ'
#         Word 5: 4 sylls
#           Span: classes=['syll', 'long'], content='Ἀ'
#           Span: classes=['syll', 'long'], content='σώ'
#           Span: classes=['syll', 'short'], content='πι'
#           Span: classes=['syll', 'short', 'worddiv'], content='χον'
#         Word 6: 1 sylls
#           Span: classes=['syll', 'long'], content='ἐν'
#         Word 7: 2 sylls
#           Span: classes=['syll', 'short'], content='τρό'
#           Span: classes=['syll', 'long', 'worddiv'], content='πῳ'
#       Final result: '[κοῦ]{φα }{βι}[βῶν]{τα· }[Λυ][δῷ ]{γὰρ }[Ἀ][σώ]{πι}{χον }[ἐν ]{τρό}[πῳ]'
#       Extracted syllables: '[κοῦ]{φα }{βι}[βῶν]{τα· }[Λυ][δῷ ]{γὰρ }[Ἀ][σώ]{πι}{χον }[ἐν ]{τρό}[πῳ]'
#       Child line 6: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='ἔν'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='με'
#           Span: classes=['syll', 'short'], content='λέ'
#           Span: classes=['syll', 'long'], content='ταις'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'long'], content='εί'
#           Span: classes=['syll', 'long'], content='δων'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='ἔ'
#           Span: classes=['syll', 'short'], content='μο'
#           Span: classes=['syll', 'long', 'worddiv'], content='λον,'
#       Final result: '[ἔν ]{με}{λέ}[ταις ]{ἀ}[εί][δων ]{ἔ}{μο}[λον,]'
#       Extracted syllables: '[ἔν ]{με}{λέ}[ταις ]{ἀ}[εί][δων ]{ἔ}{μο}[λον,]'
#       Child line 7: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='οὕ'
#           Span: classes=['syll', 'short'], content='νεκʼ'
#         Word 2: 6 sylls
#           Span: classes=['syll', 'short'], content='Ὀ'
#           Span: classes=['syll', 'long'], content='λυμ'
#           Span: classes=['syll', 'short'], content='πι'
#           Span: classes=['syll', 'short'], content='ό'
#           Span: classes=['syll', 'long'], content='νι'
#           Span: classes=['syll', 'short', 'worddiv'], content='κος'
#         Word 3: 1 sylls
#           Span: classes=['syll', 'long'], content='ἁ'
#         Word 4: 4 sylls
#           Span: classes=['syll', 'short'], content='Μι'
#           Span: classes=['syll', 'short'], content='νυ'
#           Span: classes=['syll', 'long'], content='εί'
#           Span: classes=['syll', 'long', 'worddiv'], content='α'
#       Final result: '[οὕ]{νεκʼ }{Ὀ}[λυμ]{πι}{ό}[νι]{κος }[ἁ ]{Μι}{νυ}[εί][α]'
#       Extracted syllables: '[οὕ]{νεκʼ }{Ὀ}[λυμ]{πι}{ό}[νι]{κος }[ἁ ]{Μι}{νυ}[εί][α]'
#       Child line 8: classes ['line', 'checked', 'fifth']
#       Found 5 word spans
#         Word 1: 1 sylls
#           Span: classes=['syll', 'long'], content='σεῦ'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'short'], content='ἕ'
#           Span: classes=['syll', 'long'], content='κα'
#           Span: classes=['syll', 'short', 'resolved', 'res1'], content='τι.'
#         Word 3: 5 sylls
#           Span: classes=['syll', 'short', 'resolved', 'res2'], content='με'
#           Span: classes=['syll', 'long'], content='λαν'
#           Span: classes=['syll', 'long'], content='τει'
#           Span: classes=['syll', 'short'], content='χέ'
#           Span: classes=['syll', 'short'], content='α'
#         Word 4: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='νῦν'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'short'], content='δό'
#           Span: classes=['syll', 'long', 'worddiv'], content='μον'
#       Final result: '[σεῦ ]{ἕ}[κα]{€τι. }{€με}[λαν][τει]{χέ}{α }[νῦν ]{δό}[μον]'
#       Extracted syllables: '[σεῦ ]{ἕ}[κα]{€τι. }{€με}[λαν][τει]{χέ}{α }[νῦν ]{δό}[μον]'
#       Child line 9: classes ['line', 'checked']
#       Found 7 word spans
#         Word 1: 4 sylls
#           Span: classes=['syll', 'long'], content='Φερ'
#           Span: classes=['syll', 'short'], content='σε'
#           Span: classes=['syll', 'short'], content='φό'
#           Span: classes=['syll', 'long'], content='νας'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long', 'unres'], content='ἔλθʼ,'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'long'], content='Ἀ'
#           Span: classes=['syll', 'long'], content='χοῖ,'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='πα'
#           Span: classes=['syll', 'long'], content='τρὶ'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'short'], content='κλυ'
#           Span: classes=['syll', 'long'], content='τὰν'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='φέ'
#           Span: classes=['syll', 'long'], content='ροισʼ'
#         Word 7: 4 sylls
#           Span: classes=['syll', 'long'], content='ἀγ'
#           Span: classes=['syll', 'short'], content='γε'
#           Span: classes=['syll', 'short'], content='λί'
#           Span: classes=['syll', 'long', 'worddiv'], content='αν,'
#       Final result: '[Φερ]{σε}{φό}[νας ][ἔλθʼ, ][Ἀ][χοῖ, ]{πα}[τρὶ ]{κλυ}[τὰν ]{φέ}[ροισʼ ][ἀγ]{γε}{λί}[αν,]'
#       Extracted syllables: '[Φερ]{σε}{φό}[νας ][ἔλθʼ, ][Ἀ][χοῖ, ]{πα}[τρὶ ]{κλυ}[τὰν ]{φέ}[ροισʼ ][ἀγ]{γε}{λί}[αν,]'
#       Child line 10: classes ['line', 'checked']
#       Found 8 word spans
#         Word 1: 3 sylls
#           Span: classes=['syll', 'long'], content='Κλεό'
#           Span: classes=['syll', 'long'], content='δα'
#           Span: classes=['syll', 'short', 'worddiv'], content='μον'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'long'], content='ὄφρʼ'
#         Word 3: 2 sylls
#           Span: classes=['syll', 'short'], content='ἰ'
#           Span: classes=['syll', 'long', 'worddiv'], content='δοῖσʼ,'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'long'], content='υἱ'
#           Span: classes=['syll', 'short'], content='ὸν'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long'], content='εἴ'
#           Span: classes=['syll', 'long', 'worddiv'], content='πῃς'
#         Word 6: 2 sylls
#           Span: classes=['syll', 'short'], content='ὅ'
#           Span: classes=['syll', 'short'], content='τι'
#         Word 7: 1 sylls
#           Span: classes=['syll', 'long', 'worddiv'], content='οἱ'
#         Word 8: 2 sylls
#           Span: classes=['syll', 'short'], content='νέ'
#           Span: classes=['syll', 'long', 'worddiv'], content='αν'
#       Final result: '[Κλεό][δα]{μον }[ὄφρʼ ]{ἰ}[δοῖσʼ, ][υἱ]{ὸν }[εἴ][πῃς ]{ὅ}{τι }[οἱ ]{νέ}[αν]'
#       Extracted syllables: '[Κλεό][δα]{μον }[ὄφρʼ ]{ἰ}[δοῖσʼ, ][υἱ]{ὸν }[εἴ][πῃς ]{ὅ}{τι }[οἱ ]{νέ}[αν]'
#       Child line 11: classes ['line', 'checked']
#       Found 4 word spans
#         Word 1: 2 sylls
#           Span: classes=['syll', 'long'], content='κόλ'
#           Span: classes=['syll', 'long', 'unres', 'worddiv'], content='ποις'
#         Word 2: 1 sylls
#           Span: classes=['syll', 'short'], content='παρʼ'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'long'], content='εὐ'
#           Span: classes=['syll', 'long'], content='δό'
#           Span: classes=['syll', 'long', 'worddiv'], content='ξοις'
#         Word 4: 2 sylls
#           Span: classes=['syll', 'short'], content='Πί'
#           Span: classes=['syll', 'long', 'worddiv'], content='σας'
#       Final result: '[κόλ][ποις ]{παρʼ }[εὐ][δό][ξοις ]{Πί}[σας]'
#       Extracted syllables: '[κόλ][ποις ]{παρʼ }[εὐ][δό][ξοις ]{Πί}[σας]'
#       Child line 12: classes ['line', 'checked']
#       Found 5 word spans
#         Word 1: 5 sylls
#           Span: classes=['syll', 'long'], content='ἐ'
#           Span: classes=['syll', 'short'], content='στε'
#           Span: classes=['syll', 'short'], content='φά'
#           Span: classes=['syll', 'long'], content='νω'
#           Span: classes=['syll', 'short'], content='σε'
#         Word 2: 3 sylls
#           Span: classes=['syll', 'long'], content='κυ'
#           Span: classes=['syll', 'short'], content='δί'
#           Span: classes=['syll', 'long'], content='μων'
#         Word 3: 3 sylls
#           Span: classes=['syll', 'short'], content='ἀ'
#           Span: classes=['syll', 'short'], content='έ'
#           Span: classes=['syll', 'long'], content='θλων'
#         Word 4: 3 sylls
#           Span: classes=['syll', 'short'], content='πτε'
#           Span: classes=['syll', 'long'], content='ροῖ'
#           Span: classes=['syll', 'short', 'worddiv'], content='σι'
#         Word 5: 2 sylls
#           Span: classes=['syll', 'long'], content='χαί'
#           Span: classes=['syll', 'long', 'worddiv'], content='ταν.'
#       Final result: '[ἐ]{στε}{φά}[νω]{σε }[κυ]{δί}[μων ]{ἀ}{έ}[θλων ]{πτε}[ροῖ]{σι }[χαί][ταν.]'
#       Extracted syllables: '[ἐ]{στε}{φά}[νω]{σε }[κυ]{δί}[μων ]{ἀ}{έ}[θλων ]{πτε}[ροῖ]{σι }[χαί][ταν.]'
#     Total lines collected: 12

# %% [markdown]
# ## 3. Compilation

# %%
from src.compile import process_file

process_file("data/scan/ht_olympians_triads.xml", "data/compiled/ht_olympians_triads.xml")
# Out:
# Processed XML saved to data/compiled/ht_olympians_triads.xml
